# %%
from googlesearch import search
import urllib

# %%
query = "Assiteca spa"
my_results_list = []
for i in search(query,        # The query you want to run
                #tld = 'com',  # The top level domain
                lang = 'it',  # The language
                num = 10,     # Number of results per page
                #start = 0,    # First result to retrieve
                stop = 11,  # Last result to retrieve 
                pause =3.0,  # Lapse between HTTP requests
               ):
    my_results_list.append(i)
    print(i)
    #print(len(my_results_list))
    #if len(my_results_list()) == 10:
       # break
print("\n")
print(len(my_results_list))
print("\n")
for line in urllib.request.urlopen(my_results_list[0]):
    print (line)
# Out:
# https://www.assiteca.it/
# https://www.paginegialle.it/milano-mi/assicurazioni/assiteca
# https://www.reportaziende.it/assiteca_spa_internazionale_di_brokeraggio_assicurativo
# https://www.bloomberg.com/profile/company/ASSI:IM
# https://www.linkedin.com/company/assiteca-spa-internazionale-di-brokeraggio-assicurativo-in-forma-abbreviata-assiteca-s.p.a.
# https://it.investing.com/equities/assiteca-spa-internazionale
# https://www.asefibrokers.com/broker/assiteca-internazionale-di-brokeraggio-assicurativo
# https://www.trend-online.com/ansa/assiteca-perfeziona-il-progetto-di-fusione-della-controllata-arena-broker-387038/
# https://www.assinews.it/tag/assiteca-spa/
# https://confindustriachpe.it/imprese/tutte-le-imprese/4045-assiteca-spa
# https://www.china-italy.com/it/socio/assiteca-spa
#
#
# 11
#
#
# b'\n'
# b'<!DOCTYPE html>\n'
# b'<html lang="it-IT">\n'
# b'\t<head>\n'
# b'\t\t<meta charset="UTF-8" />\n'
# b'\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n'
# b'\t\t<link rel="pingback" href="https://www.assiteca.it/xmlrpc.php" />\n'
# b'        <script type="application/ld+json">\n'
# b'            {\n'
# b'                "@context": "https://schema.org",\n'
# b'                "@type": "WebPage",\n'
# b'                "name": "Assiteca",\n'
# b'                "description": "Il pi\xc3\xb9 grande broker assicurativo italiano"\n'
# b'\n'
# b'            }\n'
# b'        </script>\n'
# b'        <script type="application/ld+json">\n'
# b'            {\n'
# b'                "@context": "https://schema.org",\n'
# b'                "@type": "Organization",\n'
# b'                "address": {\n'
# b'                    "@type": "PostalAddress",\n'
# b'                    "addressLocality": "Milano, Italia",\n'
# b'                    "postalCode": "20135",\n'
# b'                    "streetAddress": "via G. Sigieri 14"\n'
# b'                },\n'
# b'                "email": "assiteca@assiteca.it",\n'
# b'                "faxNumber": "02.54679.350",\n'
# b'                "member": [\n'
# b'                    {\n'
# b'                        "@type": "Organization"\n'
# b'                    },\n'
# b'                    {\n'
# b'                        "@type": "Organization"\n'
# b'                    }\n'
# b'                ],\n'
# b'                "name": "assiteca.it (ASSI)",\n'
# b'                "telephone": "02.54679.1"\n'
# b'            }\n'
# b'\n'
# b'        </script>\n'
# b'\n'
# b'\t\t<style type="text/css">\t\t\t.heateorSssInstagramBackground{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}\n'
# b'\t\t\t\t\t\t\t\t\t\t\t.heateor_sss_horizontal_sharing .heateorSssSharing,.heateor_sss_standard_follow_icons_container .heateorSssSharing{\n'
# b'\t\t\t\t\t\t\tcolor: #fff;\n'
# b'\t\t\t\t\t\tborder-width: 0px;\n'
# b'\t\t\tborder-style: solid;\n'
# b'\t\t\tborder-color: transparent;\n'
# b'\t\t}\n'
# b'\t\t\t\t.heateor_sss_horizontal_sharing .heateorSssTCBackground{\n'
# b'\t\t\tcolor:#666;\n'
# b'\t\t}\n'
# b'\t\t\t\t.heateor_sss_horizontal_sharing .heateorSssSharing:hover,.heateor_sss_standard_follow_icons_container .heateorSssSharing:hover{\n'
# b'\t\t\t\t\t\tborder-color: transparent;\n'
# b'\t\t}\n'
# b'\t\t.heateor_sss_vertical_sharing .heateorSssSharing,.heateor_sss_floating_follow_icons_container .heateorSssSharing{\n'
# b'\t\t\t\t\t\t\tcolor: #fff;\n'
# b'\t\t\t\t\t\tborder-width: 0px;\n'
# b'\t\t\tborder-style: solid;\n'
# b'\t\t\tborder-color: transparent;\n'
# b'\t\t}\n'
# b'\t\t\t\t.heateor_sss_vertical_sharing .heateorSssTCBackground{\n'
# b'\t\t\tcolor:#666;\n'
# b'\t\t}\n'
# b'\t\t\t\t.heateor_sss_vertical_sharing .heateorSssSharing:hover,.heateor_sss_floating_follow_icons_container .heateorSssSharing:hover{\n'
# b'\t\t\t\t\t\tborder-color: transparent;\n'
# b'\t\t}\n'
# b'\t\t\n'
# b'\t\t@media screen and (max-width:783px) {.heateor_sss_vertical_sharing{display:none!important}}@media screen and (max-width:783px) {.heateor_sss_floating_follow_icons_container{display:none!important}}div.heateor_sss_mobile_footer{display:none;}@media screen and (max-width:783px){i.heateorSssTCBackground{background-color:white!important}div.heateor_sss_bottom_sharing{width:100%!important;left:0!important;}div.heateor_sss_bottom_sharing li{width:20% !important;}div.heateor_sss_bottom_sharing .heateorSssSharing{width: 100% !important;}div.heateor_sss_bottom_sharing div.heateorSssTotalShareCount{font-size:1em!important;line-height:28px!important}div.heateor_sss_bottom_sharing div.heateorSssTotalShareText{font-size:.7em!important;line-height:0px!important}div.heateor_sss_mobile_footer{display:block;height:40px;}.heateor_sss_bottom_sharing{padding:0!important;display:block!important;width: auto!important;bottom:-2px!important;top: auto!important;}.heateor_sss_bottom_sharing .heateor_sss_square_count{line-height: inherit;}.heateor_sss_bottom_sharing .heateorSssSharingArrow{display:none;}.heateor_sss_bottom_sharing .heateorSssTCBackground{margin-right: 1.1em !important}}.entry-content .heateorSssClear {\r\n'
# b'    clear: both;\r\n'
# b'    padding-top: 0px;\r\n'
# b'    padding-bottom: 2px;\r\n'
# b'}div.heateorSssSharingArrow{display:none}</style><link rel="alternate" hreflang="it-it" href="https://www.assiteca.it" />\n'
# b'<link rel="alternate" hreflang="en-us" href="https://www.assiteca.it/en/" />\n'
# b'<link rel="alternate" hreflang="es-es" href="https://www.assiteca.it/es/" />\n'
# b'<link rel="alternate" hreflang="zh-cn" href="https://www.assiteca.it/zh-hans/" />\n'
# b'\n'
# b'\t<!-- This site is optimized with the Yoast SEO plugin v14.9 - https://yoast.com/wordpress/plugins/seo/ -->\n'
# b'\t<title>ASSITECA - il pi\xc3\xb9 grande broker assicurativo italiano</title>\n'
# b'\t<meta name="description" content="ASSITECA \xc3\xa8 il pi\xc3\xb9 grande broker assicurativo italiano e offre servizi professionali e consulenza sulla gestione integrata dei rischi aziendali." />\n'
# b'\t<meta name="robots" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n'
# b'\t<link rel="canonical" href="https://www.assiteca.it/" />\n'
# b'\t<meta property="og:locale" content="it_IT" />\n'
# b'\t<meta property="og:type" content="website" />\n'
# b'\t<meta property="og:title" content="ASSITECA - il pi\xc3\xb9 grande broker assicurativo italiano" />\n'
# b'\t<meta property="og:description" content="ASSITECA \xc3\xa8 il pi\xc3\xb9 grande broker assicurativo italiano e offre servizi professionali e consulenza sulla gestione integrata dei rischi aziendali." />\n'
# b'\t<meta property="og:url" content="https://www.assiteca.it/" />\n'
# b'\t<meta property="og:site_name" content="Assiteca" />\n'
# b'\t<meta property="article:modified_time" content="2020-09-17T09:39:49+00:00" />\n'
# b'\t<meta property="og:image" content="https://www.assiteca.it/wp-content/uploads/2015/09/Logo-Assiteca-Consultative-Broker-200x200.jpg" />\n'
# b'\t<meta property="og:image:width" content="218" />\n'
# b'\t<meta property="og:image:height" content="200" />\n'
# b'\t<meta name="twitter:card" content="summary" />\n'
# b'\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.assiteca.it/#organization","name":"ASSITECA spa","url":"https://www.assiteca.it/","sameAs":[],"logo":{"@type":"ImageObject","@id":"https://www.assiteca.it/#logo","inLanguage":"it-IT","url":"https://www.assiteca.it/wp-content/uploads/2019/06/Logo_Assiteca_Pantone.jpg","width":1651,"height":911,"caption":"ASSITECA spa"},"image":{"@id":"https://www.assiteca.it/#logo"}},{"@type":"WebSite","@id":"https://www.assiteca.it/#website","url":"https://www.assiteca.it/","name":"Assiteca","description":"","publisher":{"@id":"https://www.assiteca.it/#organization"},"potentialAction":[{"@type":"SearchAction","target":"https://www.assiteca.it/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"it-IT"},{"@type":"ImageObject","@id":"https://www.assiteca.it/#primaryimage","inLanguage":"it-IT","url":"https://www.assiteca.it/wp-content/uploads/2015/09/Logo-Assiteca-Consultative-Broker-200x200.jpg","width":218,"height":200,"caption":"Logo Assiteca Consultative Broker"},{"@type":"WebPage","@id":"https://www.assiteca.it/#webpage","url":"https://www.assiteca.it/","name":"ASSITECA - il pi\\u00f9 grande broker assicurativo italiano","isPartOf":{"@id":"https://www.assiteca.it/#website"},"about":{"@id":"https://www.assiteca.it/#organization"},"primaryImageOfPage":{"@id":"https://www.assiteca.it/#primaryimage"},"datePublished":"2015-09-29T09:25:08+00:00","dateModified":"2020-09-17T09:39:49+00:00","description":"ASSITECA \\u00e8 il pi\\u00f9 grande broker assicurativo italiano e offre servizi professionali e consulenza sulla gestione integrata dei rischi aziendali.","inLanguage":"it-IT","potentialAction":[{"@type":"ReadAction","target":["https://www.assiteca.it/"]}]}]}</script>\n'
# b'\t<!-- / Yoast SEO plugin. -->\n'
# b'\n'
# b'\n'
# b"<link rel='dns-prefetch' href='//fonts.googleapis.com' />\n"
# b"<link rel='dns-prefetch' href='//s.w.org' />\n"
# b'<link rel="alternate" type="application/rss+xml" title="Assiteca &raquo; Feed" href="https://www.assiteca.it/feed/" />\n'
# b'<link rel="alternate" type="application/rss+xml" title="Assiteca &raquo; Feed dei commenti" href="https://www.assiteca.it/comments/feed/" />\n'
# b'<!-- This site uses the Google Analytics by MonsterInsights plugin v7.12.2 - Using Analytics tracking - https://www.monsterinsights.com/ -->\n'
# b'<script type="text/javascript" data-cfasync="false">\n'
# b"\tvar mi_version         = '7.12.2';\n"
# b'\tvar mi_track_user      = true;\n'
# b"\tvar mi_no_track_reason = '';\n"
# b'\t\n'
# b"\tvar disableStr = 'ga-disable-UA-330989-1';\n"
# b'\n'
# b'\t/* Function to detect opted out users */\n'
# b'\tfunction __gaTrackerIsOptedOut() {\n'
# b"\t\treturn document.cookie.indexOf(disableStr + '=true') > -1;\n"
# b'\t}\n'
# b'\n'
# b'\t/* Disable tracking if the opt-out cookie exists. */\n'
# b'\tif ( __gaTrackerIsOptedOut() ) {\n'
# b'\t\twindow[disableStr] = true;\n'
# b'\t}\n'
# b'\n'
# b'\t/* Opt-out function */\n'
# b'\tfunction __gaTrackerOptout() {\n'
# b"\t  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';\n"
# b'\t  window[disableStr] = true;\n'
# b'\t}\n'
# b'\n'
# b"\tif ( 'undefined' === typeof gaOptout ) {\n"
# b'\t\tfunction gaOptout() {\n'
# b'\t\t\t__gaTrackerOptout();\n'
# b'\t\t}\n'
# b'\t}\n'
# b'\t\n'
# b'\tif ( mi_track_user ) {\n'
# b"\t\t(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n"
# b'\t\t\t(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n'
# b'\t\t\tm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n'
# b"\t\t})(window,document,'script','//www.google-analytics.com/analytics.js','__gaTracker');\n"
# b'\n'
# b"\t\t__gaTracker('create', 'UA-330989-1', 'auto');\n"
# b"\t\t__gaTracker('set', 'forceSSL', true);\n"
# b"\t\t__gaTracker('set', 'anonymizeIp', true);\n"
# b"\t\t__gaTracker('send','pageview');\n"
# b'\t} else {\n'
# b'\t\tconsole.log( "" );\n'
# b'\t\t(function() {\n'
# b'\t\t\t/* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */\n'
# b'\t\t\tvar noopfn = function() {\n'
# b'\t\t\t\treturn null;\n'
# b'\t\t\t};\n'
# b'\t\t\tvar noopnullfn = function() {\n'
# b'\t\t\t\treturn null;\n'
# b'\t\t\t};\n'
# b'\t\t\tvar Tracker = function() {\n'
# b'\t\t\t\treturn null;\n'
# b'\t\t\t};\n'
# b'\t\t\tvar p = Tracker.prototype;\n'
# b'\t\t\tp.get = noopfn;\n'
# b'\t\t\tp.set = noopfn;\n'
# b'\t\t\tp.send = noopfn;\n'
# b'\t\t\tvar __gaTracker = function() {\n'
# b'\t\t\t\tvar len = arguments.length;\n'
# b'\t\t\t\tif ( len === 0 ) {\n'
# b'\t\t\t\t\treturn;\n'
# b'\t\t\t\t}\n'
# b'\t\t\t\tvar f = arguments[len-1];\n'
# b"\t\t\t\tif ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {\n"
# b'\t\t\t\t\tconsole.log( \'Funzione non attiva __gaTracker(\' + arguments[0] + " ....) perch\xc3\xa9 non sei stato tracciato. " + mi_no_track_reason );\n'
# b'\t\t\t\t\treturn;\n'
# b'\t\t\t\t}\n'
# b'\t\t\t\ttry {\n'
# b'\t\t\t\t\tf.hitCallback();\n'
# b'\t\t\t\t} catch (ex) {\n'
# b'\n'
# b'\t\t\t\t}\n'
# b'\t\t\t};\n'
# b'\t\t\t__gaTracker.create = function() {\n'
# b'\t\t\t\treturn new Tracker();\n'
# b'\t\t\t};\n'
# b'\t\t\t__gaTracker.getByName = noopnullfn;\n'
# b'\t\t\t__gaTracker.getAll = function() {\n'
# b'\t\t\t\treturn [];\n'
# b'\t\t\t};\n'
# b'\t\t\t__gaTracker.remove = noopfn;\n'
# b"\t\t\twindow['__gaTracker'] = __gaTracker;\n"
# b'\t\t\t\t\t})();\n'
# b'\t\t}\n'
# b'</script>\n'
# b'<!-- / Google Analytics by MonsterInsights -->\n'
# b'\t\t<script type="text/javascript">\n'
# b'\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.0\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/13.0.0\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/www.assiteca.it\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.5.1"}};\n'
# b'\t\t\t!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);\n'
# b'\t\t</script>\n'
# b'\t\t<style type="text/css">\n'
# b'img.wp-smiley,\n'
# b'img.emoji {\n'
# b'\tdisplay: inline !important;\n'
# b'\tborder: none !important;\n'
# b'\tbox-shadow: none !important;\n'
# b'\theight: 1em !important;\n'
# b'\twidth: 1em !important;\n'
# b'\tmargin: 0 .07em !important;\n'
# b'\tvertical-align: -0.1em !important;\n'
# b'\tbackground: none !important;\n'
# b'\tpadding: 0 !important;\n'
# b'}\n'
# b'</style>\n'
# b"\t<link rel='stylesheet' id='wp-block-library-css'  href='https://www.assiteca.it/wp-includes/css/dist/block-library/style.min.css?ver=5.5.1' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='contact-form-7-css'  href='https://www.assiteca.it/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.2.2' type='text/css' media='all' />\n"
# b"<style id='contact-form-7-inline-css' type='text/css'>\n"
# b'.wpcf7 .wpcf7-recaptcha iframe {margin-bottom: 0;}.wpcf7 .wpcf7-recaptcha[data-align="center"] > div {margin: 0 auto;}.wpcf7 .wpcf7-recaptcha[data-align="right"] > div {margin: 0 0 0 auto;}\n'
# b'</style>\n'
# b"<link rel='stylesheet' id='cookie-notice-front-css'  href='https://www.assiteca.it/wp-content/plugins/cookie-notice/css/front.min.css?ver=5.5.1' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='siteorigin-panels-front-css'  href='https://www.assiteca.it/wp-content/plugins/siteorigin-panels/css/front-flex.min.css?ver=2.11.2' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='wpml-legacy-horizontal-list-0-css'  href='//www.assiteca.it/wp-content/plugins/sitepress-multilingual-cms/templates/language-switchers/legacy-list-horizontal/style.css?ver=1' type='text/css' media='all' />\n"
# b"<style id='wpml-legacy-horizontal-list-0-inline-css' type='text/css'>\n"
# b'.wpml-ls-statics-shortcode_actions{background-color:#ffffff;}.wpml-ls-statics-shortcode_actions, .wpml-ls-statics-shortcode_actions .wpml-ls-sub-menu, .wpml-ls-statics-shortcode_actions a {border-color:#cdcdcd;}.wpml-ls-statics-shortcode_actions a {color:#444444;background-color:#ffffff;}.wpml-ls-statics-shortcode_actions a:hover,.wpml-ls-statics-shortcode_actions a:focus {color:#000000;background-color:#eeeeee;}.wpml-ls-statics-shortcode_actions .wpml-ls-current-language>a {color:#444444;background-color:#ffffff;}.wpml-ls-statics-shortcode_actions .wpml-ls-current-language:hover>a, .wpml-ls-statics-shortcode_actions .wpml-ls-current-language>a:focus {color:#000000;background-color:#eeeeee;}\n'
# b'</style>\n'
# b"<link rel='stylesheet' id='parent-style-css'  href='https://www.assiteca.it/wp-content/themes/cargopress-pt/style.css?ver=5.5.1' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='cargopress-custom-css-css'  href='https://www.assiteca.it/wp-content/themes/cargopress-pt-child/assets/sass/custom.css?ver=5.5.1' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='cargopress-main-css'  href='https://www.assiteca.it/wp-content/themes/cargopress-pt-child/style.css?ver=1.0' type='text/css' media='all' />\n"
# b"<style id='cargopress-main-inline-css' type='text/css'>\n"
# b'/* WP Customizer start */\n'
# b'.top, .top-navigation .sub-menu > li > a { background-color: #f5f5f5; }\n'
# b'.top, .top-navigation .sub-menu > li > a { border-bottom-color: #ededed; }\n'
# b'.top-navigation .sub-menu > li > .sub-menu { border-left-color: #ededed; }\n'
# b'.top, .top-navigation > li > a, .top-navigation .sub-menu > li > a { color: #aaaaaa; }\n'
# b'.top-navigation > li > a:hover, .top-navigation > li > a:focus, .top-navigation .sub-menu > li > a:focus, .top-navigation .sub-menu > li > a:hover { color: #919191; }\n'
# b'.header__widgets, .header__logo, .header__container::before, .header__container::after, .header__logo::after { background-color: #ffffff; }\n'
# b'@media (max-width: 991px) { .header__container, .main-navigation .sub-menu>li>a { background-color: #ffffff; } }\n'
# b'.header, .header .icon-box__title { color: #aaaaaa; }\n'
# b'.header .icon-box__subtitle { color: #474747; }\n'
# b'.breadcrumbs { background-color: #ffffff; }\n'
# b'.breadcrumbs a::before, .breadcrumbs a::after { background-color: #e6e6e6; }\n'
# b'.breadcrumbs a { color: #444444; }\n'
# b'.breadcrumbs a:hover { color: #373737; }\n'
# b'.breadcrumbs { color: #aaaaaa; }\n'
# b'@media (min-width: 992px) { .header__container, .is-sticky-nav .header__navigation { background-color: #162267; } }\n'
# b'.navbar-toggle, .jumbotron { background-color: #162267; }\n'
# b'.navbar-toggle:hover { background-color: #00094e; }\n'
# b'@media (min-width: 992px) { .social-icons__link, .social-icons__link:hover { color: #162267; } }\n'
# b'@media (min-width: 992px) { .main-navigation > li > a, .main-navigation .menu-item-has-children::after, .main-navigation > li:hover > a, .main-navigation > li:focus > a { color: #ffffff; } }\n'
# b'@media (min-width: 992px) { .main-navigation .menu-item-has-children:hover > a, .main-navigation .sub-menu > li > a, .main-navigation ul.sub-menu { background-color: #ffffff; } }\n'
# b'@media (min-width: 992px) { .main-navigation .sub-menu > li > a, .main-navigation .sub-menu .menu-item-has-children::after { color: #999999; } }\n'
# b'@media (min-width: 992px) { .main-navigation .menu-item-has-children:hover > a, .main-navigation .sub-menu > li > a:hover, .main-navigation .menu-item-has-children:hover::after, .main-navigation .sub-menu .menu-item-has-children:hover::after { color: #1f425d; } }\n'
# b'@media (max-width: 991px) { .main-navigation > li > a { color: #444444; } }\n'
# b'@media (max-width: 991px) { .main-navigation > li:hover > a, .main-navigation > li:focus > a { color: #1f425d; } }\n'
# b'@media (max-width: 991px) { .main-navigation .sub-menu > li > a { color: #999999; } }\n'
# b'@media (max-width: 991px) { .main-navigation .sub-menu > li > a:hover { color: #1f425d; } }\n'
# b'.main-title { background-image: url(""); }\n'
# b'.main-title h1, .main-title h2 { color: #444444; }\n'
# b'.main-title h3 { color: #aaaaaa; }\n'
# b'body, .widget_pw_icon_box .icon-box__subtitle { color: #000000; }\n'
# b'h1, h2, h3, h4, h5, h6, hentry__title, .hentry__title a, .page-box__title a { color: #444444; }\n'
# b'.header .icon-box .fa, .number-counter__icon, hr.hr-quote::after { color: #e21f2f; }\n'
# b'.latest-news__date, .sticky .btn--post, .main-navigation > .current-menu-item > a::after, .main-navigation > li:hover > a::after, .main-navigation > li:focus > a::after, body.woocommerce-page span.onsale, .woocommerce span.onsale { background-color: #e21f2f; }\n'
# b'.latest-news__date::after { border-top-color: #ce0b1b; }\n'
# b'.sticky .btn--post { border-color: #e21f2f; }\n'
# b'.btn-info, .btn-primary, .testimonial__quote::before, .widget_search .search-submit, .sidebar .widget_nav_menu ul > li.current-menu-item a, .pagination .current, body.woocommerce-page .widget_shopping_cart_content .buttons .checkout, body.woocommerce-page nav.woocommerce-pagination ul li span.current, body.woocommerce-page button.button.alt, body.woocommerce-page div.product .woocommerce-tabs ul.tabs li.active, body.woocommerce-page .woocommerce-error a.button, body.woocommerce-page .woocommerce-info a.button, body.woocommerce-page .woocommerce-message a.button, .woocommerce-cart .wc-proceed-to-checkout a.checkout-button, body.woocommerce-page #payment #place_order, body.woocommerce-page #review_form #respond input#submit, .woocommerce button.button.alt:disabled, .woocommerce button.button.alt:disabled:hover, .woocommerce button.button.alt:disabled[disabled], .woocommerce button.button.alt:disabled[disabled]:hover, .widget_calendar caption { background-color: #4ab9cf; }\n'
# b'.btn-info, .btn-primary, body.woocommerce-page .widget_shopping_cart_content .buttons .checkout { border-color: #4ab9cf; }\n'
# b'.btn-info:hover, .open > .btn-info.dropdown-toggle, .btn-info.active, .btn-info.focus, .btn-info:active, .btn-info:focus, .btn-primary:hover, .btn-primary:focus, .btn-primary:active, .open > .btn-primary.dropdown-toggle, .btn-primary.active, .btn-primary.focus, .widget_search .search-submit:hover, .widget_search .search-submit:focus, body.woocommerce-page .widget_shopping_cart_content .buttons .checkout:hover, body.woocommerce-page button.button.alt:hover, body.woocommerce-page .woocommerce-error a.button:hover, body.woocommerce-page .woocommerce-info a.button:hover, body.woocommerce-page .woocommerce-message a.button:hover, .woocommerce-cart .wc-proceed-to-checkout a.checkout-button:hover, body.woocommerce-page #payment #place_order:hover, body.woocommerce-page #review_form #respond input#submit:hover { background-color: #3dacc2; }\n'
# b'.btn-info:hover, .open > .btn-info.dropdown-toggle, .btn-info.active, .btn-info.focus, .btn-info:active, .btn-info:focus, .btn-primary:hover, .btn-primary:focus, .btn-primary:active, .open > .btn-primary.dropdown-toggle, .btn-primary.active, .btn-primary.focus, body.woocommerce-page .widget_shopping_cart_content .buttons .checkout:hover { border-color: #3dacc2; }\n'
# b'a, .latest-news--more-news::after, .widget_pw_icon_box .icon-box:hover .fa, body.woocommerce-page ul.products li.product a:hover img, .woocommerce ul.products li.product a:hover img, body.woocommerce-page ul.products li.product .price, .woocommerce ul.products li.product .price, body.woocommerce-page .star-rating, .woocommerce .star-rating, body.woocommerce-page div.product p.price, body.woocommerce-page p.stars a { color: #4ab9cf; }\n'
# b'a:hover, a:focus { color: #3dacc2; }\n'
# b'.widget_pw_icon_box .icon-box:hover, .logo-panel img:hover { border-bottom-color: #4ab9cf; }\n'
# b'.footer-top, .footer::before, .footer::after, .footer-top::before, .footer-top::after { background-color: #162267; }\n'
# b'.footer .icon-container--square, .footer .icon-container--circle { color: #162267; }\n'
# b'.footer-top__headings { color: #ffffff; }\n'
# b'.footer-top, .footer-top .textwidget { color: #ffffff; }\n'
# b'.footer .widget_nav_menu ul > li > a { color: #ffffff; }\n'
# b'.footer-bottom { background-color: #162f42; }\n'
# b'.footer-bottom { color: #577186; }\n'
# b'.footer-bottom a { color: #eeeeee; }\n'
# b'.footer-bottom a:hover { color: #fbfbfb; }\n'
# b'/* WP Customizer end */\n'
# b'\n'
# b'\t\t\t@media (min-width: 992px) {\n'
# b'\t\t\t\t.header__logo {\n'
# b'\t\t\t\t\twidth: 270px;\n'
# b'\t\t\t\t}\n'
# b'\t\t\t\t.header__widgets {\n'
# b'\t\t\t\t\twidth: calc(100% - 270px);\n'
# b'\t\t\t\t}\n'
# b'\t\t\t\t.header__navigation {\n'
# b'\t\t\t\t\twidth: 100%;\n'
# b'\t\t\t\t}\n'
# b'\t\t\t}\n'
# b'\t\t\t@media (min-width: 1200px) {\n'
# b'\t\t\t\t.header__navigation {\n'
# b'\t\t\t\t\twidth: calc(100% - 300px);\n'
# b'\t\t\t\t\tmargin-left: 300px;\n'
# b'\t\t\t\t}\n'
# b'\t\t\t}\n'
# b'.main-title { background: #f5f5f5 linear-gradient(90deg, #f5f5f5, #eeeeee) }\n'
# b'\n'
# b'\t\t\t@media (min-width: 992px){\n'
# b'\t\t\t\t.header__logo img {\n'
# b'\t\t\t\t\tmargin-top: 0px;\n'
# b'\t\t\t\t}\n'
# b'\t\t\t}\n'
# b'\n'
# b'</style>\n'
# b"<link rel='stylesheet' id='google-fonts-css'  href='//fonts.googleapis.com/css?family=Roboto+Condensed%3A400%2C700%7CRoboto%3A400%2C700%7CSource+Sans+Pro%3A700%2C900&#038;subset=latin' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='slb_core-css'  href='https://www.assiteca.it/wp-content/plugins/simple-lightbox/client/css/app.css?ver=2.8.1' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='heateor_sss_frontend_css-css'  href='https://www.assiteca.it/wp-content/plugins/sassy-social-share/public/css/sassy-social-share-public.css?ver=3.3.12' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='heateor_sss_sharing_default_svg-css'  href='https://www.assiteca.it/wp-content/plugins/sassy-social-share/admin/css/sassy-social-share-svg.css?ver=3.3.12' type='text/css' media='all' />\n"
# b"<link rel='stylesheet' id='msl-main-css'  href='https://www.assiteca.it/wp-content/plugins/master-slider/public/assets/css/masterslider.main.css?ver=3.6.0' type='text/css' media='all' />\n"
# b"<script type='text/javascript' id='jquery-core-js-extra'>\n"
# b'/* <![CDATA[ */\n'
# b'var SDT_DATA = {"ajaxurl":"https:\\/\\/www.assiteca.it\\/wp-admin\\/admin-ajax.php","siteUrl":"https:\\/\\/www.assiteca.it\\/","pluginsUrl":"https:\\/\\/www.assiteca.it\\/wp-content\\/plugins","isAdmin":""};\n'
# b'/* ]]> */\n'
# b'</script>\n'
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp' id='jquery-core-js'></script>\n"
# b"<script type='text/javascript' id='dtgs_nonce_frontend-js-after'>\n"
# b'var DTGS_NONCE_FRONTEND = "e820479062"\n'
# b'</script>\n'
# b"<script type='text/javascript' id='monsterinsights-frontend-script-js-extra'>\n"
# b'/* <![CDATA[ */\n'
# b'var monsterinsights_frontend = {"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[]","home_url":"https:\\/\\/www.assiteca.it","hash_tracking":"false"};\n'
# b'/* ]]> */\n'
# b'</script>\n'
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/plugins/google-analytics-for-wordpress/assets/js/frontend.min.js?ver=7.12.2' id='monsterinsights-frontend-script-js'></script>\n"
# b"<script type='text/javascript' id='cookie-notice-front-js-extra'>\n"
# b'/* <![CDATA[ */\n'
# b'var cnArgs = {"ajaxUrl":"https:\\/\\/www.assiteca.it\\/wp-admin\\/admin-ajax.php","nonce":"c6e02b6900","hideEffect":"fade","position":"top","onScroll":"0","onScrollOffset":"100","onClick":"0","cookieName":"cookie_notice_accepted","cookieTime":"2592000","cookieTimeRejected":"2592000","cookiePath":"\\/","cookieDomain":"","redirection":"0","cache":"0","refuse":"1","revokeCookies":"0","revokeCookiesOpt":"automatic","secure":"1","coronabarActive":"0"};\n'
# b'/* ]]> */\n'
# b'</script>\n'
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/plugins/cookie-notice/js/front.min.js?ver=1.3.2' id='cookie-notice-front-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/plugins/flowpaper-lite-pdf-flipbook/assets/lity/lity.min.js' id='lity-js-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/themes/cargopress-pt-child/assets/js/jquery-ui.min.js?ver=5.5.1' id='cargopress-jquery-ui-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/themes/cargopress-pt-child/assets/js/custom_common.js?ver=5.5.1' id='cargopress-custom-js-common-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/themes/cargopress-pt/assets/js/modernizr.custom.24530.js' id='cargopress-modernizr-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/themes/cargopress-pt/bower_components/picturefill/dist/picturefill.min.js?ver=1.2.0' id='cargopress-picturefill-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/themes/cargopress-pt-child/assets/js/custom_home.js?ver=5.5.1' id='cargopress-custom-home-js-js'></script>\n"
# b'<link rel="https://api.w.org/" href="https://www.assiteca.it/wp-json/" /><link rel="alternate" type="application/json" href="https://www.assiteca.it/wp-json/wp/v2/pages/17" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://www.assiteca.it/xmlrpc.php?rsd" />\n'
# b'<link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://www.assiteca.it/wp-includes/wlwmanifest.xml" /> \n'
# b'<meta name="generator" content="WordPress 5.5.1" />\n'
# b"<link rel='shortlink' href='https://www.assiteca.it/' />\n"
# b'<link rel="alternate" type="application/json+oembed" href="https://www.assiteca.it/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.assiteca.it%2F" />\n'
# b'<link rel="alternate" type="text/xml+oembed" href="https://www.assiteca.it/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.assiteca.it%2F&#038;format=xml" />\n'
# b'<meta name="generator" content="WPML ver:4.2.4 stt:61,1,27,2;" />\n'
# b'<style>GI Confindustria - S. Margherita Ligure 2016\n'
# b'.msp-cn-32-4 { font-family:"Roboto Condensed";font-weight:700;font-size:30px;line-height:normal;color:#ffffff; } \n'
# b'.msp-cn-32-5 { font-family:"Roboto";font-weight:700;font-size:40px;line-height:normal;white-space:nowrap;color:#ffffff; } \n'
# b'.msp-cn-32-6 { font-weight:500;font-size:16px;line-height:normal; } \n'
# b'.msp-cn-32-8 { font-family:"Roboto";font-weight:700;font-size:40px;line-height:normal;white-space:nowrap;color:#ffffff; } \n'
# b'.msp-cn-32-9 { font-weight:500;font-size:16px;line-height:normal; } \n'
# b'\n'
# b'Calendario Assiteca 2020\n'
# b'Premio Pietro Calabrese\n'
# b'GI Confindustria - S. Margherita Ligure 2016\n'
# b'Calendario Assiteca 2019\n'
# b'Forum Assiteca "Nuova Responsabilit\xc3\xa0 Sanitaria" - Roma, 6 novembre 2017\n'
# b'GI Confindustria - S. Margherita Ligure 2016\n'
# b'Forum Assiteca "Nuova Responsabilit\xc3\xa0 Sanitaria" - Roma, 6 novembre 2017\n'
# b'Forum Assiteca "Nuova Responsabilit\xc3\xa0 Sanitaria" - Roma, 6 novembre 2017\n'
# b'GI Confindustria - S. Margherita Ligure 2016</style>\n'
# b"<script>var ms_grabbing_curosr = 'https://www.assiteca.it/wp-content/plugins/master-slider/public/assets/css/common/grabbing.cur', ms_grab_curosr = 'https://www.assiteca.it/wp-content/plugins/master-slider/public/assets/css/common/grab.cur';</script>\n"
# b'<meta name="generator" content="MasterSlider 3.6.0 - Responsive Touch Image Slider | avt.li/msf" />\n'
# b'                <style type="text/css" media="all"\n'
# b'                       id="siteorigin-panels-layouts-head">/* Layout 17 */ #pgc-17-0-0 , #pgc-17-0-1 , #pgc-17-0-2 , #pgc-17-0-3 , #pgc-17-3-0 , #pgc-17-3-1 , #pgc-17-3-2 , #pgc-17-3-3 { width:25%;width:calc(25% - ( 0.75 * 30px ) ) } #pg-17-0 , #pg-17-1 , #pg-17-2 , #pg-17-5 , #pl-17 .so-panel { margin-bottom:30px } #pgc-17-1-0 , #pgc-17-2-0 , #pgc-17-4-0 , #pgc-17-6-0 { width:100%;width:calc(100% - ( 0 * 30px ) ) } #pg-17-3 { margin-bottom:85px } #pg-17-4 , #pl-17 .so-panel:last-child { margin-bottom:0px } #pgc-17-5-0 , #pgc-17-5-1 , #pgc-17-5-2 { width:33.3333%;width:calc(33.3333% - ( 0.66666666666667 * 30px ) ) } #pg-17-6 { margin-bottom:70px } #pg-17-0.panel-no-style, #pg-17-0.panel-has-style > .panel-row-style { -webkit-align-items:flex-start;align-items:flex-start } #pg-17-4> .panel-row-style { background-color:#f5f5f5;padding:25px;margin-top:-45px } #pg-17-5> .panel-row-style { background-color:#a39f90;padding:65px } #pg-17-6> .panel-row-style { background-color:#f5f5f5;padding:25px;margin-top:-45px;margin-bottom:70px } @media (max-width:991px){ #pg-17-0.panel-no-style, #pg-17-0.panel-has-style > .panel-row-style , #pg-17-1.panel-no-style, #pg-17-1.panel-has-style > .panel-row-style , #pg-17-2.panel-no-style, #pg-17-2.panel-has-style > .panel-row-style , #pg-17-3.panel-no-style, #pg-17-3.panel-has-style > .panel-row-style , #pg-17-4.panel-no-style, #pg-17-4.panel-has-style > .panel-row-style , #pg-17-5.panel-no-style, #pg-17-5.panel-has-style > .panel-row-style , #pg-17-6.panel-no-style, #pg-17-6.panel-has-style > .panel-row-style { -webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column } #pg-17-0 > .panel-grid-cell , #pg-17-0 > .panel-row-style > .panel-grid-cell , #pg-17-1 > .panel-grid-cell , #pg-17-1 > .panel-row-style > .panel-grid-cell , #pg-17-2 > .panel-grid-cell , #pg-17-2 > .panel-row-style > .panel-grid-cell , #pg-17-3 > .panel-grid-cell , #pg-17-3 > .panel-row-style > .panel-grid-cell , #pg-17-4 > .panel-grid-cell , #pg-17-4 > .panel-row-style > .panel-grid-cell , #pg-17-5 > .panel-grid-cell , #pg-17-5 > .panel-row-style > .panel-grid-cell , #pg-17-6 > .panel-grid-cell , #pg-17-6 > .panel-row-style > .panel-grid-cell { width:100%;margin-right:0 } #pgc-17-0-0 , #pgc-17-0-1 , #pgc-17-0-2 , #pgc-17-3-0 , #pgc-17-3-1 , #pgc-17-3-2 , #pgc-17-5-0 , #pgc-17-5-1 { margin-bottom:30px } #pl-17 .panel-grid-cell { padding:0 } #pl-17 .panel-grid .panel-grid-cell-empty { display:none } #pl-17 .panel-grid .panel-grid-cell-mobile-last { margin-bottom:0px }  } </style><link rel="icon" href="https://www.assiteca.it/wp-content/uploads/2019/06/Logo_Assiteca_Foglia-150x150.jpg" sizes="32x32" />\n'
# b'<link rel="icon" href="https://www.assiteca.it/wp-content/uploads/2019/06/Logo_Assiteca_Foglia-300x300.jpg" sizes="192x192" />\n'
# b'<link rel="apple-touch-icon" href="https://www.assiteca.it/wp-content/uploads/2019/06/Logo_Assiteca_Foglia-300x300.jpg" />\n'
# b'<meta name="msapplication-TileImage" content="https://www.assiteca.it/wp-content/uploads/2019/06/Logo_Assiteca_Foglia-300x300.jpg" />\n'
# b'\t</head>\n'
# b'\n'
# b'\t<body class="home page-template page-template-template-front-page-slider page-template-template-front-page-slider-php page page-id-17 cookies-not-set _masterslider _ms_version_3.6.0 siteorigin-panels siteorigin-panels-before-js siteorigin-panels-home">\n'
# b'\t<div class="boxed-container">\n'
# b'\n'
# b'\t\n'
# b'\t<div class="header__container">\n'
# b'\t\t<div class="container">\n'
# b'\t\t\t<header class="header" role="banner">\n'
# b'\t\t\t\t<div class="header__logo">\n'
# b'\t\t\t\t\t<a href="https://www.assiteca.it">\n'
# b'\t\t\t\t\t\t\t\t\t\t\t\t<img src="https://www.assiteca.it/wp-content/uploads/2018/01/Logo_Assiteca_RGB.jpg" alt="Assiteca" srcset="https://www.assiteca.it/wp-content/uploads/2018/01/Logo_Assiteca_RGB.jpg" class="img-responsive"  width="1351" height="446"  />\n'
# b'\t\t\t\t\t\t\t\t\t\t\t</a>\n'
# b'\t\t\t\t\t<button type="button" class="navbar-toggle" data-toggle="collapse" data-target="#cargopress-navbar-collapse">\n'
# b'\t\t\t\t\t\t<span class="navbar-toggle__text">MENU</span>\n'
# b'\t\t\t\t\t\t<span class="navbar-toggle__icon-bar">\n'
# b'\t\t\t\t\t\t\t<span class="icon-bar"></span>\n'
# b'\t\t\t\t\t\t\t<span class="icon-bar"></span>\n'
# b'\t\t\t\t\t\t\t<span class="icon-bar"></span>\n'
# b'\t\t\t\t\t\t</span>\n'
# b'\t\t\t\t\t</button>\n'
# b'\t\t\t\t</div>\n'
# b'\t\t\t\t<div class="header__navigation  js-sticky-offset">\n'
# b'\t\t\t\t\t<nav class="collapse  navbar-collapse" role="navigation" aria-label="Main Menu" id="cargopress-navbar-collapse">\n'
# b'\t\t\t\t\t\t<ul id="menu-menu-principale" class="main-navigation  js-main-nav  js-dropdown" role="menubar"><li id="menu-item-149" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-149"><a href="https://www.assiteca.it/chi-siamo/">Chi siamo</a></li>\n'
# b'<li id="menu-item-7341" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7341"><a href="https://www.assiteca.it/consultative-broker/">Perch\xc3\xa9 sceglierci</a></li>\n'
# b'<li id="menu-item-7230" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-7230" aria-haspopup="true" aria-expanded="false" tabindex="0"><a href="https://www.assiteca.it/servizi-di-consulenza/">Servizi di consulenza</a>\n'
# b'<ul class="sub-menu">\n'
# b'\t<li id="menu-item-7255" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7255"><a href="https://www.assiteca.it/servizi-di-consulenza/rischi-operativi/">Rischi operativi</a></li>\n'
# b'\t<li id="menu-item-7236" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7236"><a href="https://www.assiteca.it/servizi-di-consulenza/rischi-compliance/">Rischi compliance</a></li>\n'
# b'\t<li id="menu-item-7254" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7254"><a href="https://www.assiteca.it/servizi-di-consulenza/rischi-finanziari/">Rischi finanziari</a></li>\n'
# b'\t<li id="menu-item-7256" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7256"><a href="https://www.assiteca.it/servizi-di-consulenza/rischi-strategici/">Rischi strategici</a></li>\n'
# b'</ul>\n'
# b'</li>\n'
# b'<li id="menu-item-295" class="short-item menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-295" aria-haspopup="true" aria-expanded="false" tabindex="0"><a href="https://www.assiteca.it/soluzioni-assicurative/">Soluzioni assicurative</a>\n'
# b'<ul class="sub-menu">\n'
# b'\t<li id="menu-item-7486" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7486"><a href="https://www.assiteca.it/soluzioni-assicurative-rischi-operativi/">Soluzioni assicurative per i rischi operativi</a></li>\n'
# b'\t<li id="menu-item-7485" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7485"><a href="https://www.assiteca.it/soluzioni-assicurative-per-i-rischi-compliance/">Soluzioni assicurative per i rischi compliance</a></li>\n'
# b'\t<li id="menu-item-7484" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7484"><a href="https://www.assiteca.it/soluzioni-assicurative-per-i-rischi-finanziari/">Soluzioni assicurative per i rischi finanziari</a></li>\n'
# b'\t<li id="menu-item-7483" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7483"><a href="https://www.assiteca.it/soluzioni-assicurative-per-i-rischi-strategici/">Soluzioni assicurative per i rischi strategici</a></li>\n'
# b'</ul>\n'
# b'</li>\n'
# b'<li id="menu-item-249" class="short-item menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-249" aria-haspopup="true" aria-expanded="false" tabindex="0"><a href="https://www.assiteca.it/divisioni-speciali/">Divisioni</a>\n'
# b'<ul class="sub-menu">\n'
# b'\t<li id="menu-item-260" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-260"><a href="https://www.assiteca.it/divisioni-speciali/tecnica/">Tecnica</a></li>\n'
# b'\t<li id="menu-item-259" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-259"><a href="https://www.assiteca.it/divisioni-speciali/trasporti/">Trasporti</a></li>\n'
# b'\t<li id="menu-item-15380" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15380"><a href="https://www.assiteca.it/divisioni-speciali/motor/">Motor</a></li>\n'
# b'\t<li id="menu-item-18271" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18271"><a href="https://www.assiteca.it/divisioni-speciali/divisione-insurtech/">Insurtech</a></li>\n'
# b'\t<li id="menu-item-258" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-258"><a href="https://www.assiteca.it/divisioni-speciali/assiteca-agricoltura/">Assiteca Agricoltura</a></li>\n'
# b'\t<li id="menu-item-257" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-257"><a href="https://www.assiteca.it/divisioni-speciali/energie-rinnovabili/">Energie Rinnovabili</a></li>\n'
# b'\t<li id="menu-item-256" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-256"><a href="https://www.assiteca.it/divisioni-speciali/crediti-commerciali/">Crediti Commerciali</a></li>\n'
# b'\t<li id="menu-item-255" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-255"><a href="https://www.assiteca.it/divisioni-speciali/pubblica-amministrazione/">Enti Pubblici</a></li>\n'
# b'\t<li id="menu-item-7905" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7905"><a href="https://www.assiteca.it/divisioni-speciali/sanita/">Sanit\xc3\xa0</a></li>\n'
# b'\t<li id="menu-item-254" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-254"><a href="https://www.assiteca.it/divisioni-speciali/employee-benefits/">Employee Benefit e Welfare</a></li>\n'
# b'\t<li id="menu-item-253" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-253"><a href="https://www.assiteca.it/divisioni-speciali/affinity/">Affinity e Small Business</a></li>\n'
# b'\t<li id="menu-item-252" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-252"><a href="https://www.assiteca.it/divisioni-speciali/internazionale/">Internazionale</a></li>\n'
# b'\t<li id="menu-item-251" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-251"><a href="https://www.assiteca.it/divisioni-speciali/costruzioni/">Costruzioni e Infrastrutture</a></li>\n'
# b'\t<li id="menu-item-250" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-250"><a href="https://www.assiteca.it/divisioni-speciali/cauzioni-e-fideiussioni/">Cauzioni e Fideiussioni</a></li>\n'
# b'</ul>\n'
# b'</li>\n'
# b'<li id="menu-item-4076" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4076"><a href="https://www.assiteca.it/le-nostre-iniziative/">Academy e Iniziative</a></li>\n'
# b'<li id="menu-item-18403" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18403"><a href="https://www.assiteca.it/blog/">Blog</a></li>\n'
# b'<li id="menu-item-6654" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6654"><a href="https://www.assiteca.it/investor-relations/">Investor Relations</a></li>\n'
# b'<li id="menu-item-1253" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1253"><a href="https://www.assiteca.it/comunicati-stampa/">Stampa</a></li>\n'
# b'<li id="menu-item-87" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-87"><a href="https://www.assiteca.it/contatti/">Contatti</a></li>\n'
# b'</ul>\t\t\t\t\t</nav>\n'
# b'\t\t\t\t</div>\n'
# b'\t\t\t\t<div class="header__widgets">\n'
# b'\t\t\t\t<div class="widget  widget_execphp">\t\t\t<div class="execphpwidget">\t<div class="widget header-custom  widget_text"><h2 class="widgettitle">L\xe2\x80\x99unica realt\xc3\xa0 di servizi professionali creata per assistere le aziende nella gestione integrata dei rischi d\xe2\x80\x99impresa</h2>\r\n'
# b'\t<div class="textwidget"></div>\r\n'
# b'\t</div>\r\n'
# b'</div>\n'
# b'\t\t</div><div class="widget  widget_execphp">\t\t\t<div class="execphpwidget">\t<a class="btn  btn-primary" href="https://portaleclienti.assiteca.it/login" target="_self" rel="nofollow">gestione online clienti</a>\r\n'
# b'\t</div>\n'
# b'\t\t</div><div class="widget  widget_icl_lang_sel_widget">\n'
# b'<div class="lang_sel_list_horizontal wpml-ls-sidebars-header-widgets wpml-ls wpml-ls-legacy-list-horizontal" id="lang_sel_list">\n'
# b'\t<ul><li class="icl-it wpml-ls-slot-header-widgets wpml-ls-item wpml-ls-item-it wpml-ls-current-language wpml-ls-first-item wpml-ls-item-legacy-list-horizontal">\n'
# b'\t\t\t\t<a href="https://www.assiteca.it" class="wpml-ls-link"><img class="wpml-ls-flag iclflag" src="https://www.assiteca.it/wp-content/uploads/flags/it.png" alt="it" title="Italiano"></a>\n'
# b'\t\t\t</li><li class="icl-en wpml-ls-slot-header-widgets wpml-ls-item wpml-ls-item-en wpml-ls-item-legacy-list-horizontal">\n'
# b'\t\t\t\t<a href="https://www.assiteca.it/en/" class="wpml-ls-link"><img class="wpml-ls-flag iclflag" src="https://www.assiteca.it/wp-content/uploads/flags/en.png" alt="en" title="English"></a>\n'
# b'\t\t\t</li><li class="icl-es wpml-ls-slot-header-widgets wpml-ls-item wpml-ls-item-es wpml-ls-item-legacy-list-horizontal">\n'
# b'\t\t\t\t<a href="https://www.assiteca.it/es/" class="wpml-ls-link"><img class="wpml-ls-flag iclflag" src="https://www.assiteca.it/wp-content/uploads/flags/es.png" alt="es" title="Espa\xc3\xb1ol"></a>\n'
# b'\t\t\t</li><li class="icl-zh-hans wpml-ls-slot-header-widgets wpml-ls-item wpml-ls-item-zh-hans wpml-ls-last-item wpml-ls-item-legacy-list-horizontal">\n'
# b'\t\t\t\t<a href="https://www.assiteca.it/zh-hans/" class="wpml-ls-link"><img class="wpml-ls-flag iclflag" src="https://www.assiteca.it/wp-content/uploads/flags/zh.png" alt="zh-hans" title="\xe7\xae\x80\xe4\xbd\x93\xe4\xb8\xad\xe6\x96\x87"></a>\n'
# b'\t\t\t</li></ul>\n'
# b'</div></div>\t\t\t\t</div>\n'
# b'\t\t\t\t\t\t\t</header>\n'
# b'\t\t</div>\n'
# b'\t</div>\n'
# b'<div class="jumbotron  jumbotron--with-captions">\n'
# b'\t<div class="carousel  slide  js-jumbotron-slider" id="headerCarousel" data-ride="carousel" data-interval="4000">\n'
# b'\n'
# b'\t\t<!-- Wrapper for slides -->\n'
# b'\t\t<div class="carousel-inner">\n'
# b'\t\t\n'
# b'\t\t\t<div class="item  active">\n'
# b'\t\t\t\t\t\t\t\t<img src="https://www.assiteca.it/wp-content/uploads/2019/03/hp-slideracademy-480x150.jpg" srcset="https://www.assiteca.it/wp-content/uploads/2019/03/hp-slideracademy.jpg 1920w, https://www.assiteca.it/wp-content/uploads/2019/03/hp-slideracademy-960x300.jpg 960w, https://www.assiteca.it/wp-content/uploads/2019/03/hp-slideracademy-480x150.jpg 480w" sizes="100vw" alt="ASSITECA academy">\n'
# b'\t\t\t\t\t\t\t\t\t\t\t\t<div class="container">\n'
# b'\t\t\t\t\t<div class="jumbotron-content">\n'
# b'\t\t\t\t\t\t\t\t\t\t\t<div class="jumbotron-content__title">\n'
# b'\t\t\t\t\t\t\t<h2>ASSITECA academy</h2>\n'
# b'\t\t\t\t\t\t</div>\n'
# b'\t\t\t\t\t\t<div class="jumbotron-content__description">\n'
# b'\t\t\t\t\t\t\t<p style="text-align: left;"><a class="btn    btn-primary" href="https://www.assiteca.it/le-nostre-iniziative/assiteca-academy/" target="_self">CLICCA E SCOPRI</a></p>\n'
# b'\t\t\t\t\t\t</div>\n'
# b'\t\t\t\t\t</div>\n'
# b'\t\t\t\t</div>\n'
# b'\t\t\t\t\t\t\t</div>\n'
# b'\n'
# b'\t\t\n'
# b'\t\t\t<div class="item ">\n'
# b'\t\t\t\t\t\t\t\t<img src="https://www.assiteca.it/wp-content/uploads/2019/01/hp-report-sostenibilit\xc3\xa018-480x150.jpg" srcset="https://www.assiteca.it/wp-content/uploads/2019/01/hp-report-sostenibilit\xc3\xa018-1920x600.jpg 1920w, https://www.assiteca.it/wp-content/uploads/2019/01/hp-report-sostenibilit\xc3\xa018-960x300.jpg 960w, https://www.assiteca.it/wp-content/uploads/2019/01/hp-report-sostenibilit\xc3\xa018-480x150.jpg 480w" sizes="100vw" alt="Report di Sostenibilit\xc3\xa0">\n'
# b'\t\t\t\t\t\t\t\t\t\t\t\t<div class="container">\n'
# b'\t\t\t\t\t<div class="jumbotron-content">\n'
# b'\t\t\t\t\t\t\t\t\t\t\t<div class="jumbotron-content__title">\n'
# b'\t\t\t\t\t\t\t<h2>Report di Sostenibilit\xc3\xa0</h2>\n'
# b'\t\t\t\t\t\t</div>\n'
# b'\t\t\t\t\t\t<div class="jumbotron-content__description">\n'
# ...
# b'\t\t<div class="page-box__content">\n'
# b'\t\t\t<h5 class="page-box__title  text-uppercase"><a href="https://www.assiteca.it/chi-siamo/responsabilita-sociale/">Responsabilit\xc3\xa0 Sociale</a></h5>\n'
# b"\t\t\t<p>L'attenzione nei confronti della collettivit\xc3\xa0, della cultura, del territorio e del sociale caratterizza da sempre l'attivit\xc3\xa0 di ASSITECA. Un comportamento equo e giusto, che tenga conto dell'impatto che le decisioni e le strategie adottate &hellip;</p>\n"
# b'\t\t\t\t<p><a href="https://www.assiteca.it/chi-siamo/responsabilita-sociale/" class="read-more  read-more--page-box">Read more</a></p>\n'
# b'\t\t</div>\n'
# b'\t</div>\n'
# b'\n'
# b'</div></div></div><div id="pgc-17-5-1"  class="panel-grid-cell" ><div id="panel-17-5-1-0" class="so-panel widget widget_pw_featured_page widget-featured-page panel-first-child panel-last-child" data-index="19" ><div class="box-home-red panel-widget-style panel-widget-style-for-17-5-1-0" >\n'
# b'\n'
# b'\t<div class="page-box  page-box--block">\n'
# b'\t\t\t<a class="page-box__picture" href="https://www.assiteca.it/servizi-di-consulenza/"><img src="https://www.assiteca.it/wp-content/uploads/2017/06/servizi-consulenza-box-360x240.jpg" width="360" height="240" srcset="https://www.assiteca.it/wp-content/uploads/2017/06/servizi-consulenza-box-360x240.jpg 360w, https://www.assiteca.it/wp-content/uploads/2017/06/servizi-consulenza-box.jpg 362w" sizes="(min-width: 992px) 360px, calc(100vw - 30px)" class="wp-post-image" alt="Servizi di consulenza"></a>\n'
# b'\t\t<div class="page-box__content">\n'
# b'\t\t\t<h5 class="page-box__title  text-uppercase"><a href="https://www.assiteca.it/servizi-di-consulenza/">Servizi di consulenza</a></h5>\n'
# b"\t\t\t<p>Offrire una gestione integrata dei rischi attraverso una metodologia di lavoro che coniuga consulenza e intermediazione assicurativa consente di\xc2\xa0 costruire un efficace sistema di controllo utile a prevenire, mitigare e proteggere l'azienda.I &hellip;</p>\n"
# b'\t\t\t\t<p><a href="https://www.assiteca.it/servizi-di-consulenza/" class="read-more  read-more--page-box">Read more</a></p>\n'
# b'\t\t</div>\n'
# b'\t</div>\n'
# b'\n'
# b'</div></div></div><div id="pgc-17-5-2"  class="panel-grid-cell" ><div id="panel-17-5-2-0" class="so-panel widget widget_pw_featured_page widget-featured-page panel-first-child panel-last-child" data-index="20" ><div class="box-home-blue panel-widget-style panel-widget-style-for-17-5-2-0" >\n'
# b'\n'
# b'\t<div class="page-box  page-box--block">\n'
# b'\t\t\t<a class="page-box__picture" href="https://www.assiteca.it/soluzioniassicurative/"><img src="https://www.assiteca.it/wp-content/uploads/2016/01/soluzioni-assicurative-cubo-360x240.jpg" width="360" height="240" srcset="https://www.assiteca.it/wp-content/uploads/2016/01/soluzioni-assicurative-cubo-360x240.jpg 360w, https://www.assiteca.it/wp-content/uploads/2016/01/soluzioni-assicurative-cubo.jpg 364w" sizes="(min-width: 992px) 360px, calc(100vw - 30px)" class="wp-post-image" alt="Soluzioni Assicurative"></a>\n'
# b'\t\t<div class="page-box__content">\n'
# b'\t\t\t<h5 class="page-box__title  text-uppercase"><a href="https://www.assiteca.it/soluzioniassicurative/">Soluzioni Assicurative</a></h5>\n'
# b'\t\t\t<p></p>\n'
# b'\t\t\t\t<p><a href="https://www.assiteca.it/soluzioniassicurative/" class="read-more  read-more--page-box">Read more</a></p>\n'
# b'\t\t</div>\n'
# b'\t</div>\n'
# b'\n'
# b'</div></div></div></div></div><div id="pg-17-6"  class="panel-grid panel-has-style" ><div class="siteorigin-panels-stretch panel-row-style panel-row-style-for-17-6" data-stretch-type="full" ><div id="pgc-17-6-0"  class="panel-grid-cell panel-grid-cell-empty" ></div></div></div></div><div class=\'heateor_sss_sharing_container heateor_sss_vertical_sharing heateor_sss_bottom_sharing\' style=\'width:44px;right: -14px;top: 140px;-webkit-box-shadow:none;box-shadow:none;\' heateor-sss-data-href=\'https://www.assiteca.it\'><ul class="heateor_sss_sharing_ul"><li class=""><i style="width:40px;height:40px;margin:0;" alt="Linkedin" Title="Linkedin" class="heateorSssSharing heateorSssLinkedinBackground" onclick=\'heateorSssPopup("http://www.linkedin.com/shareArticle?mini=true&url=https%3A%2F%2Fwww.assiteca.it&title=Home")\'><ss style="display:block;" class="heateorSssSharingSvg heateorSssLinkedinSvg"></ss></i></li><li class=""><i style="width:40px;height:40px;margin:0;" alt="Twitter" Title="Twitter" class="heateorSssSharing heateorSssTwitterBackground" onclick=\'heateorSssPopup("http://twitter.com/intent/tweet?text=Home&url=https%3A%2F%2Fwww.assiteca.it")\'><ss style="display:block;" class="heateorSssSharingSvg heateorSssTwitterSvg"></ss></i></li><li class=""><i style="width:40px;height:40px;margin:0;" alt="Email" Title="Email" class="heateorSssSharing heateorSssEmailBackground"  onclick="window.open(\'mailto:?subject=\' + decodeURIComponent(\'Home\' ).replace(\'&\', \'%26\') + \'&body=\' + decodeURIComponent(\'https%3A%2F%2Fwww.assiteca.it\' ), \'_blank\')"><ss style="display:block" class="heateorSssSharingSvg heateorSssEmailSvg"></ss></i></li><li class=""><i style="width:40px;height:40px;margin:0;" alt="Whatsapp" Title="Whatsapp" class="heateorSssSharing heateorSssWhatsappBackground"><a  href="https://web.whatsapp.com/send?text=Home https%3A%2F%2Fwww.assiteca.it" rel="nofollow noopener" target="_blank"><ss style="display:block" class="heateorSssSharingSvg heateorSssWhatsappSvg"></ss></a></i></li><li class=""><i style="width:40px;height:40px;margin:0;" alt="Print" Title="Print" class="heateorSssSharing heateorSssPrintBackground" onclick=\'window.print()\'><ss style="display:block" class="heateorSssSharingSvg heateorSssPrintSvg"></ss></i></li></ul><div class="heateorSssClear"></div></div></div>\n'
# b'\n'
# b'\n'
# b'\t<footer class="footer" role="contentinfo">\n'
# b'\t\t\t\t<div class="footer-top">\n'
# b'\t\t\t<div class="container">\n'
# b'\t\t\t\t<div class="row">\n'
# b'\t\t\t\t\t<div class="col-xs-12  col-md-4"><div class="widget  widget_execphp">\t\t\t<div class="execphpwidget"><img style="display: block; margin-top: -20px;" src="https://www.assiteca.it/wp-content/uploads/2018/01/Logo_Assiteca_white-270x190.png" alt="" />\r\n'
# b'<div style="font-size: 20px;">\r\n'
# b'ASSITECA spa<br>\r\n'
# b'Palazzo Assiteca<br>\r\n'
# b'via G. Sigieri 14 \xe2\x80\x93 20135 Milano<br>\r\n'
# b'Tel. 02.54679.1 \xe2\x80\x93 fax 02.54679.350<br>\r\n'
# b'&nbsp;\r\n'
# b'</div>\r\n'
# b'<br>\r\n'
# b'<div style="font-size: 12px;">P.IVA/Codice fiscale e numero d\xe2\x80\x99iscrizione: IT 09743130156 del Registro delle Imprese di Milano<br>\r\n'
# b'Iscritta con il numero Repertorio Economico Amministrativo 1313138<br>\r\n'
# b'Capitale sociale \xe2\x82\xac 7.617.193,51 i.v. Iscritta al R.U.I. sezione B n. 114899 del 16/04/2007<br>  \r\n'
# b'Copyright \xc2\xa9 2004-2020 Assiteca Spa\r\n'
# b'</div>  \r\n'
# b'</div>\n'
# b'\t\t</div></div><div class="col-xs-12  col-md-4"><div class="widget  widget_execphp">\t\t\t<div class="execphpwidget"><div class="widget  widget_nav_menu">\r\n'
# b'<div class="menu-menu-footer-ita-container"><ul id="menu-menu-footer-ita" class="menu"><li id="menu-item-2248" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2248"><a href="https://www.assiteca.it/chi-siamo/dove-siamo/">Dove siamo: tutti gli indirizzi</a></li>\n'
# b'<li id="menu-item-2253" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2253"><a href="https://www.assiteca.it/contatti/">Contatti</a></li>\n'
# b'<li id="menu-item-3231" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3231"><a href="https://www.assiteca.it/il-codice-delle-assicurazioni/">Il codice delle assicurazioni</a></li>\n'
# b'<li id="menu-item-2570" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2570"><a href="https://www.assiteca.it/dati-societari/">Dati societari</a></li>\n'
# b'<li id="menu-item-2569" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2569"><a href="https://www.assiteca.it/privacy/">Data Protection Policy</a></li>\n'
# b'<li id="menu-item-2708" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2708"><a href="https://www.assiteca.it/chi-siamo/cookies-policy/">Cookie policy</a></li>\n'
# b'<li id="menu-item-5889" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5889"><a href="https://www.assiteca.it/reclami/">Segnala un reclamo</a></li>\n'
# b'</ul></div></div></div>\n'
# b'\t\t</div></div><div class="col-xs-12  col-md-4"><div class="widget  widget_execphp">\t\t\t<div class="execphpwidget"><!--inizio SASSY SOCIAL SHARE -->\r\n'
# b'<div class="widget  widget-social-icons">\r\n'
# b'<div class="heateor_sss_follow_icons_container"><ul class="heateor_sss_follow_ul"><li class="heateorSssSharingRound"><i style="width:32px;height:32px;" alt="Linkedin" title="Linkedin" class="heateorSssSharing heateorSssLinkedinBackground"><a target="_blank" aria-label="Linkedin" href="https://it.linkedin.com/company/assiteca" rel="noopener"><ss style="display:block" class="heateorSssSharingSvg heateorSssLinkedinSvg"></ss></a></i></li><li class="heateorSssSharingRound"><i style="width:32px;height:32px;" alt="Twitter" title="Twitter" class="heateorSssSharing heateorSssTwitterBackground"><a target="_blank" aria-label="Twitter" href="https://twitter.com/assiteca" rel="noopener"><ss style="display:block" class="heateorSssSharingSvg heateorSssTwitterSvg"></ss></a></i></li><li class="heateorSssSharingRound"><i style="width:32px;height:32px;" alt="Youtube" title="Youtube" class="heateorSssSharing heateorSssYoutubeBackground"><a target="_blank" aria-label="Youtube" href="https://www.youtube.com/channel/UCW6sjp7Xcya3aT7fq_v4MPg" rel="noopener"><ss style="display:block" class="heateorSssSharingSvg heateorSssYoutubeSvg"></ss></a></i></li></ul><div style="clear:both"></div></div></div>\r\n'
# b'<!--fine SASSY SOCIAL SHARE -->\r\n'
# b'\r\n'
# b'    <br>\r\n'
# b'<img src="https://www.assiteca.it/wp-content/uploads/2016/02/coverholder-at-lloyds.jpg" width="50%" />\r\n'
# b'<br />\r\n'
# b'<img src="https://www.assiteca.it/wp-content/uploads/2016/02/logo-AIdAF.png" width="50%" />\r\n'
# b'<br />\r\n'
# b'<br />\r\n'
# b'<img src="https://www.assiteca.it/wp-content/uploads/2019/05/LOGO-Rating-legalit\xc3\xa0-gimp-Barra-NEGATIVO-1.png" width="80%" />\r\n'
# b'\r\n'
# b'    </div>\n'
# b'\t\t</div></div>\t\t\t\t</div>\n'
# b'\t\t\t</div>\n'
# b'\t\t</div>\n'
# b'\t\t\t\t<div class="footer-bottom">\n'
# b'\t\t\t<div class="container">\n'
# b'\t\t\t\t<div class="footer-bottom__left">\n'
# b'\t\t\t\t\t\t\t\t\t</div>\n'
# b'\t\t\t\t<div class="footer-bottom__right">\n'
# b'\t\t\t\t\t\t\t\t\t</div>\n'
# b'\t\t\t</div>\n'
# b'\t\t</div>\n'
# b'\t</footer>\n'
# b'\t</div><!-- end of .boxed-container -->\n'
# b'\n'
# b"\t<script type='text/javascript' id='contact-form-7-js-extra'>\n"
# b'/* <![CDATA[ */\n'
# b'var wpcf7 = {"apiSettings":{"root":"https:\\/\\/www.assiteca.it\\/wp-json\\/contact-form-7\\/v1","namespace":"contact-form-7\\/v1"}};\n'
# b'/* ]]> */\n'
# b'</script>\n'
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.2.2' id='contact-form-7-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-includes/js/underscore.min.js?ver=1.8.3' id='underscore-js'></script>\n"
# b"<script type='text/javascript' src='//maps.google.com/maps/api/js' id='cargopress-gmaps-js'></script>\n"
# b"<script type='text/javascript' id='cargopress-main-js-extra'>\n"
# b'/* <![CDATA[ */\n'
# b'var CargoPressVars = {"pathToTheme":"https:\\/\\/www.assiteca.it\\/wp-content\\/themes\\/cargopress-pt"};\n'
# b'/* ]]> */\n'
# b'</script>\n'
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/themes/cargopress-pt/assets/js/main.min.js?ver=1.0' id='cargopress-main-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/themes/cargopress-pt/vendor/proteusthemes/wai-aria-walker-nav-menu/wai-aria.js' id='wp-wai-aria-js'></script>\n"
# b"<script type='text/javascript' id='heateor_sss_sharing_js-js-before'>\n"
# b'function heateorSssLoadEvent(e) {var t=window.onload;if (typeof window.onload!="function") {window.onload=e}else{window.onload=function() {t();e()}}};\tvar heateorSssSharingAjaxUrl = \'https://www.assiteca.it/wp-admin/admin-ajax.php\', heateorSssCloseIconPath = \'https://www.assiteca.it/wp-content/plugins/sassy-social-share/public/../images/close.png\', heateorSssPluginIconPath = \'https://www.assiteca.it/wp-content/plugins/sassy-social-share/public/../images/logo.png\', heateorSssHorizontalSharingCountEnable = 0, heateorSssVerticalSharingCountEnable = 0, heateorSssSharingOffset = -14; var heateorSssMobileStickySharingEnabled = 1;var heateorSssCopyLinkMessage = "Link copied.";var heateorSssUrlCountFetched = [], heateorSssSharesText = \'Shares\', heateorSssShareText = \'Share\';function heateorSssPopup(e) {window.open(e,"popUpWindow","height=400,width=600,left=400,top=100,resizable,scrollbars,toolbar=0,personalbar=0,menubar=no,location=no,directories=no,status")};var heateorSssWhatsappShareAPI = "web";\n'
# b'</script>\n'
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/plugins/sassy-social-share/public/js/sassy-social-share-public.js?ver=3.3.12' id='heateor_sss_sharing_js-js'></script>\n"
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-includes/js/wp-embed.min.js?ver=5.5.1' id='wp-embed-js'></script>\n"
# b"<script type='text/javascript' id='siteorigin-panels-front-styles-js-extra'>\n"
# b'/* <![CDATA[ */\n'
# b'var panelsStyles = {"fullContainer":".boxed-container"};\n'
# b'/* ]]> */\n'
# b'</script>\n'
# b"<script type='text/javascript' src='https://www.assiteca.it/wp-content/plugins/siteorigin-panels/js/styling.min.js?ver=2.11.2' id='siteorigin-panels-front-styles-js'></script>\n"
# b'<script type="text/javascript" id="slb_context">/* <![CDATA[ */if ( !!window.jQuery ) {(function($){$(document).ready(function(){if ( !!window.SLB ) { {$.extend(SLB, {"context":["public","user_guest"]});} }})})(jQuery);}/* ]]> */</script>\n'
# b'<script type="text/javascript">document.body.className = document.body.className.replace("siteorigin-panels-before-js","");</script>\r\n'
# b'\t\t<!-- Cookie Notice plugin v1.3.2 by Digital Factory https://dfactory.eu/ -->\r\n'
# b'\t\t<div id="cookie-notice" role="banner" class="cookie-notice-hidden cookie-revoke-hidden cn-position-top" aria-label="Cookie Notice" style="background-color: rgba(0,0,0,1);"><div class="cookie-notice-container" style="color: #fff;"><span id="cn-notice-text" class="cn-text-container">Utilizziamo i cookie per essere sicuri che tu possa avere la migliore esperienza sul nostro sito. Puoi consultare la nostra policy sull\'utilizzo dei cookie in qualsiasi momento cliccando sul bottone qui sotto o nel footer del sito, dove troverai anche le istruzioni per disattivarli. <br>\r\n'
# b'Utilizamos cookies propias y de terceros para analizar nuestros servicios y mostrarte publicidad relacionados con tus preferencias, en base a un perfil elaborado a partir de tus h\xc3\xa1bitos de navegaci\xc3\xb3n. Puedes obtener m\xc3\xa1s informaci\xc3\xb3n de la pol\xc3\xadtica de cookies <a href="https://www.assiteca.it/es/quienes-somos/politica-de-cookies/">aqu\xc3\xad.</a> \r\n'
# b'</span><span id="cn-notice-buttons" class="cn-buttons-container"><a href="#" id="cn-accept-cookie" data-cookie-set="accept" class="cn-set-cookie cn-button bootstrap button" aria-label="Ok">Ok</a><a href="#" id="cn-refuse-cookie" data-cookie-set="refuse" class="cn-set-cookie cn-button bootstrap button" aria-label="No - Refuse">No - Refuse</a><a href="https://www.assiteca.it/chi-siamo/cookies-policy/" target="_blank" id="cn-more-info" class="cn-more-info cn-button bootstrap button" aria-label="Cookie Policy">Cookie Policy</a></span><a href="javascript:void(0);" id="cn-close-notice" data-cookie-set="accept" class="cn-close-icon" aria-label="Ok"></a></div>\r\n'
# b'\t\t\t\r\n'
# b'\t\t</div>\r\n'
# b'\t\t<!-- / Cookie Notice plugin -->\t</body>\n'
# b'</html>\n'

# %%
import urllib
import html2text
from bs4 import BeautifulSoup,NavigableString
soup = BeautifulSoup( urllib.request.urlopen('https://www.assiteca.it').read())
txt = soup.find('div','class','body')
#print(txt)
#print (soup.get_text().replace('\r\n',' '))
soup = soup.get_text().replace('\r\n',' ')
soup =soup.replace('\n',' ')
soup =soup.replace('\t','')
#print (soup)
#print (soup.get_text().find('\r'))
rens  = soup.split()
print("numero di parole:",len(soup.split()))
print("numero di occorenze:",rens.count("Assiteca"))
# Out:
# numero di parole: 511
# numero di occorenze: 3

# %% [markdown]
# Trasfromazione da html a text senza la rimozione delle stopword, la percentuale della presenza delle parole chiave è minore

# %%
#DA TENERE PER LA TRAFROMAZIONE DA HTML DA TEXT

from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.assiteca.it/"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)
text=text.lower()
print(text)

#conteggio parole e parole chiave con la valutazione della pertinenza 
totale_parole = len(text.split())
totale_key = text.count("assiteca")
print("numero di parole:",totale_parole)
print("numero di occorenze:",totale_key)

print("percentuale:",(totale_key / totale_parole)*100)
# Out:
# assiteca - il più grande broker assicurativo italiano
# menu
# chi siamo
# perché sceglierci
# servizi di consulenza
# rischi operativi
# rischi compliance
# rischi finanziari
# rischi strategici
# soluzioni assicurative
# soluzioni assicurative per i rischi operativi
# soluzioni assicurative per i rischi compliance
# soluzioni assicurative per i rischi finanziari
# soluzioni assicurative per i rischi strategici
# divisioni
# tecnica
# trasporti
# motor
# insurtech
# assiteca agricoltura
# energie rinnovabili
# crediti commerciali
# enti pubblici
# sanità
# employee benefit e welfare
# affinity e small business
# internazionale
# costruzioni e infrastrutture
# cauzioni e fideiussioni
# academy e iniziative
# blog
# investor relations
# stampa
# contatti
# l’unica realtà di servizi professionali creata per assistere le aziende nella gestione integrata dei rischi d’impresa
# gestione online clienti
# assiteca academy
# clicca e scopri
# report di sostenibilità
# clicca e scopri
# scarica la app assiteca per la gestione dei sinistri
# clicca e scopri
# assiteca primo broker assicurativo italiano quotato in borsa
# clicca e scopri
# contattaci
# clicca e scopri
# blog
# clicca e scopri
# chi siamoassiteca è il più grande broker assicurativo italiano. dal luglio 2015 è il primo broker quotato alla borsa italiana - segmento aim italia.
# continua
# perché
# assitecaassiteca arricchisce l’attività tradizionale di brokeraggio assicurativo con specifici servizi di consulenza
# continua
# le nostre soluzioni prodotti esclusivi e innovativi, divisioni specialistiche con competenze specifiche in particolari aree di rischio.
# continua
# leggi il blogscopri le ultime news e gli approfondimenti dedicati alla gestione del rischio
# continua
# assiteca è il primo gruppo italiano nel mercato del brokeraggio assicurativo
# e nella consulenza sulla gestione del rischio
# le nostre divisioni speciali
# affinity e small business
# assiteca agricoltura
# cauzioni e fideiussioni
# crediti commerciali
# employee benefits
# energie rinnovabili
# internazionale
# pubblica amministrazione
# costruzioni e infrastrutture
# tecnica
# trasporti
# motor
# responsabilità sociale
# l'attenzione nei confronti della collettività, della cultura, del territorio e del sociale caratterizza da sempre l'attività di assiteca. un comportamento equo e giusto, che tenga conto dell'impatto che le decisioni e le strategie adottate …
# read more
# servizi di consulenza
# offrire una gestione integrata dei rischi attraverso una metodologia di lavoro che coniuga consulenza e intermediazione assicurativa consente di  costruire un efficace sistema di controllo utile a prevenire, mitigare e proteggere l'azienda.i …
# read more
# soluzioni assicurative
# read more
# assiteca spa
# palazzo assiteca
# via g. sigieri 14 – 20135 milano
# tel. 02.54679.1 – fax 02.54679.350
# p.iva/codice fiscale e numero d’iscrizione: it 09743130156 del registro delle imprese di milano
# iscritta con il numero repertorio economico amministrativo 1313138
# capitale sociale € 7.617.193,51 i.v. iscritta al r.u.i. sezione b n. 114899 del 16/04/2007
# copyright © 2004-2020 assiteca spa
# dove siamo: tutti gli indirizzi
# contatti
# il codice delle assicurazioni
# dati societari
# data protection policy
# cookie policy
# segnala un reclamo
# utilizziamo i cookie per essere sicuri che tu possa avere la migliore esperienza sul nostro sito. puoi consultare la nostra policy sull'utilizzo dei cookie in qualsiasi momento cliccando sul bottone qui sotto o nel footer del sito, dove troverai anche le istruzioni per disattivarli.
# utilizamos cookies propias y de terceros para analizar nuestros servicios y mostrarte publicidad relacionados con tus preferencias, en base a un perfil elaborado a partir de tus hábitos de navegación. puedes obtener más información de la política de cookies aquí.
# okno - refusecookie policy
# numero di parole: 511
# numero di occorenze: 14
# percentuale: 2.73972602739726

# %% [markdown]
# PROBLEMA : essendoci parole attaccate se splitto e poi faccio in conteggio non vengono contate se invce lo faccio sul testo trovo piu parole ma non sempre correte

# %% [markdown]
# ASSUNIONE: essendo che le parole chiave si riferiscono ad Aziende è difficile che una parola esistente sia composta dal nome dell'azienda

# %% [markdown]
# Rimozione delle stopword per migliorare la rilevanza del testo rispetto alle parole chiavi

# %% [markdown]
# NOTA: SI PUÒ UTILIZZARE TESTO SENZA STOP WORD???? PERCHE VENGONO ELIMINATE NEGAZIONI

# %%
#REMOZIONE DELLE STOP WORDS

from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.corpus import stopwords
#print(stopwords.words('italian'))
text_tokens = text.split()
tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]

print(tokens_without_sw)

#riporto il testo normale senza stop word
filtered_sentence = (" ").join(tokens_without_sw)
#print(filtered_sentence)
totale_parole = len(filtered_sentence.split())
totale_key = filtered_sentence.count("assiteca")
print("numero di parole:",totale_parole)
print("numero di occorenze:",totale_key)

print("percentuale:",(totale_key / totale_parole)*100)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/riccardo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['assiteca', '-', 'grande', 'broker', 'assicurativo', 'italiano', 'menu', 'sceglierci', 'servizi', 'consulenza', 'rischi', 'operativi', 'rischi', 'compliance', 'rischi', 'finanziari', 'rischi', 'strategici', 'soluzioni', 'assicurative', 'soluzioni', 'assicurative', 'rischi', 'operativi', 'soluzioni', 'assicurative', 'rischi', 'compliance', 'soluzioni', 'assicurative', 'rischi', 'finanziari', 'soluzioni', 'assicurative', 'rischi', 'strategici', 'divisioni', 'tecnica', 'trasporti', 'motor', 'insurtech', 'assiteca', 'agricoltura', 'energie', 'rinnovabili', 'crediti', 'commerciali', 'enti', 'pubblici', 'sanità', 'employee', 'benefit', 'welfare', 'affinity', 'small', 'business', 'internazionale', 'costruzioni', 'infrastrutture', 'cauzioni', 'fideiussioni', 'academy', 'iniziative', 'blog', 'investor', 'relations', 'stampa', 'contatti', 'l’unica', 'realtà', 'servizi', 'professionali', 'creata', 'assistere', 'aziende', 'gestione', 'integrata', 'rischi', 'd’impresa', 'gestione', 'online', 'clienti', 'assiteca', 'academy', 'clicca', 'scopri', 'report', 'sostenibilità', 'clicca', 'scopri', 'scarica', 'app', 'assiteca', 'gestione', 'sinistri', 'clicca', 'scopri', 'assiteca', 'primo', 'broker', 'assicurativo', 'italiano', 'quotato', 'borsa', 'clicca', 'scopri', 'contattaci', 'clicca', 'scopri', 'blog', 'clicca', 'scopri', 'siamoassiteca', 'grande', 'broker', 'assicurativo', 'italiano.', 'luglio', '2015', 'primo', 'broker', 'quotato', 'borsa', 'italiana', '-', 'segmento', 'aim', 'italia.', 'continua', 'assitecaassiteca', 'arricchisce', 'l’attività', 'tradizionale', 'brokeraggio', 'assicurativo', 'specifici', 'servizi', 'consulenza', 'continua', 'soluzioni', 'prodotti', 'esclusivi', 'innovativi,', 'divisioni', 'specialistiche', 'competenze', 'specifiche', 'particolari', 'aree', 'rischio.', 'continua', 'leggi', 'blogscopri', 'ultime', 'news', 'approfondimenti', 'dedicati', 'gestione', 'rischio', 'continua', 'assiteca', 'primo', 'gruppo', 'italiano', 'mercato', 'brokeraggio', 'assicurativo', 'consulenza', 'gestione', 'rischio', 'divisioni', 'speciali', 'affinity', 'small', 'business', 'assiteca', 'agricoltura', 'cauzioni', 'fideiussioni', 'crediti', 'commerciali', 'employee', 'benefits', 'energie', 'rinnovabili', 'internazionale', 'pubblica', 'amministrazione', 'costruzioni', 'infrastrutture', 'tecnica', 'trasporti', 'motor', 'responsabilità', 'sociale', "l'attenzione", 'confronti', 'collettività,', 'cultura,', 'territorio', 'sociale', 'caratterizza', 'sempre', "l'attività", 'assiteca.', 'comportamento', 'equo', 'giusto,', 'conto', "dell'impatto", 'decisioni', 'strategie', 'adottate', '…', 'read', 'servizi', 'consulenza', 'offrire', 'gestione', 'integrata', 'rischi', 'attraverso', 'metodologia', 'lavoro', 'coniuga', 'consulenza', 'intermediazione', 'assicurativa', 'consente', 'costruire', 'efficace', 'sistema', 'controllo', 'utile', 'prevenire,', 'mitigare', 'proteggere', "l'azienda.i", '…', 'read', 'soluzioni', 'assicurative', 'read', 'assiteca', 'spa', 'palazzo', 'assiteca', 'via', 'g.', 'sigieri', '14', '–', '20135', 'milano', 'tel.', '02.54679.1', '–', 'fax', '02.54679.350', 'p.iva/codice', 'fiscale', 'numero', 'd’iscrizione:', '09743130156', 'registro', 'imprese', 'milano', 'iscritta', 'numero', 'repertorio', 'economico', 'amministrativo', '1313138', 'capitale', 'sociale', '€', '7.617.193,51', 'i.v.', 'iscritta', 'r.u.i.', 'sezione', 'b', 'n.', '114899', '16/04/2007', 'copyright', '©', '2004-2020', 'assiteca', 'spa', 'siamo:', 'indirizzi', 'contatti', 'codice', 'assicurazioni', 'dati', 'societari', 'data', 'protection', 'policy', 'cookie', 'policy', 'segnala', 'reclamo', 'utilizziamo', 'cookie', 'essere', 'sicuri', 'possa', 'avere', 'migliore', 'esperienza', 'sito.', 'puoi', 'consultare', 'policy', "sull'utilizzo", 'cookie', 'qualsiasi', 'momento', 'cliccando', 'bottone', 'sotto', 'footer', 'sito,', 'troverai', 'istruzioni', 'disattivarli.', 'utilizamos', 'cookies', 'propias', 'terceros', 'analizar', 'servicios', 'mostrarte', 'publicidad' ...
# numero di parole: 354
# numero di occorenze: 14
# percentuale: 3.954802259887006

# %%
str="Ciao mi, chiamo riccardo"

str1 = str.split()
print(str1)
# Out:
# ['Ciao', 'mi,', 'chiamo', 'riccardo']
