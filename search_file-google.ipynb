# %%
from googlesearch import search

import urllib

# %%
query = "assiteca spa"
my_results_list = []
for i in search(query,        # The query you want to run
                #tld = 'com',  # The top level domain
                lang = 'it',  # The language
                num = 3,     # Number of results per page
                #start = 0,    # First result to retrieve
                stop = 3,  # Last result to retrieve 
                pause =3.0,  # Lapse between HTTP requests
               ):
    my_results_list.append(i)
    print(i)
# Out:
# https://www.assiteca.it/
# https://www.paginegialle.it/milano-mi/assicurazioni/assiteca
# https://www.bloomberg.com/profile/company/ASSI:IM

# %%
import urllib
import html2text
from bs4 import BeautifulSoup,NavigableString
soup = BeautifulSoup( urllib.request.urlopen('https://www.assiteca.it/').read())
txt = soup.find('div','class','body')
#print(soup)
#print (soup.get_text().replace('\r\n',' '))
soup = soup.get_text().replace('\r\n',' ')
soup =soup.replace('\n',' ')
soup =soup.replace('\t','')
#print (soup)
#print (soup.get_text().find('\r'))
rens  = soup.split()
print("numero di parole:",len(soup.split()))
print("numero di occorenze:",rens.count("Assiteca"))
# Out:
# numero di parole: 511
# numero di occorenze: 3

# %% [markdown]
# Trasfromazione da html a text senza la rimozione delle stopword, la percentuale della presenza delle parole chiave è minore

# %%
#DA TENERE PER LA TRAFROMAZIONE DA HTML DA TEXT

from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.assiteca.it/"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)
text=text.lower()
#print(text)

#conteggio parole e parole chiave con la valutazione della pertinenza 
totale_parole = len(text.split())
totale_key = text.count("assiteca")
print("numero di parole:",totale_parole)
print("numero di occorenze:",totale_key)

print("percentuale:",(totale_key / totale_parole)*100)
# Out:
# numero di parole: 511
# numero di occorenze: 14
# percentuale: 2.73972602739726

# %% [markdown]
# PROBLEMA : essendoci parole attaccate se splitto e poi faccio in conteggio non vengono contate se invce lo faccio sul testo trovo piu parole ma non sempre correte

# %% [markdown]
# ASSUNIONE: essendo che le parole chiave si riferiscono ad Aziende è difficile che una parola esistente sia composta dal nome dell'azienda

# %% [markdown]
# Rimozione delle stopword per migliorare la rilevanza del testo rispetto alle parole chiavi

# %% [markdown]
# NOTA: SI PUÒ UTILIZZARE TESTO SENZA STOP WORD???? PERCHE VENGONO ELIMINATE NEGAZIONI

# %%
#REMOZIONE DELLE STOP WORDS

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
#print(stopwords.words('italian'))
text_tokens = text.split()
tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]

print(tokens_without_sw)

#riporto il testo normale senza stop word
filtered_sentence = (" ").join(tokens_without_sw)
print(filtered_sentence)
totale_parole = len(filtered_sentence.split())
totale_key = filtered_sentence.count("assiteca")
print("numero di parole:",totale_parole)
print("numero di occorenze:",totale_key)

print("percentuale:",(totale_key / totale_parole)*100)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/riccardo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['assiteca', '-', 'grande', 'broker', 'assicurativo', 'italiano', 'menu', 'sceglierci', 'servizi', 'consulenza', 'rischi', 'operativi', 'rischi', 'compliance', 'rischi', 'finanziari', 'rischi', 'strategici', 'soluzioni', 'assicurative', 'soluzioni', 'assicurative', 'rischi', 'operativi', 'soluzioni', 'assicurative', 'rischi', 'compliance', 'soluzioni', 'assicurative', 'rischi', 'finanziari', 'soluzioni', 'assicurative', 'rischi', 'strategici', 'divisioni', 'tecnica', 'trasporti', 'motor', 'insurtech', 'assiteca', 'agricoltura', 'energie', 'rinnovabili', 'crediti', 'commerciali', 'enti', 'pubblici', 'sanità', 'employee', 'benefit', 'welfare', 'affinity', 'small', 'business', 'internazionale', 'costruzioni', 'infrastrutture', 'cauzioni', 'fideiussioni', 'academy', 'iniziative', 'blog', 'investor', 'relations', 'stampa', 'contatti', 'l’unica', 'realtà', 'servizi', 'professionali', 'creata', 'assistere', 'aziende', 'gestione', 'integrata', 'rischi', 'd’impresa', 'gestione', 'online', 'clienti', 'assiteca', 'academy', 'clicca', 'scopri', 'report', 'sostenibilità', 'clicca', 'scopri', 'scarica', 'app', 'assiteca', 'gestione', 'sinistri', 'clicca', 'scopri', 'assiteca', 'primo', 'broker', 'assicurativo', 'italiano', 'quotato', 'borsa', 'clicca', 'scopri', 'contattaci', 'clicca', 'scopri', 'blog', 'clicca', 'scopri', 'siamoassiteca', 'grande', 'broker', 'assicurativo', 'italiano.', 'luglio', '2015', 'primo', 'broker', 'quotato', 'borsa', 'italiana', '-', 'segmento', 'aim', 'italia.', 'continua', 'assitecaassiteca', 'arricchisce', 'l’attività', 'tradizionale', 'brokeraggio', 'assicurativo', 'specifici', 'servizi', 'consulenza', 'continua', 'soluzioni', 'prodotti', 'esclusivi', 'innovativi,', 'divisioni', 'specialistiche', 'competenze', 'specifiche', 'particolari', 'aree', 'rischio.', 'continua', 'leggi', 'blogscopri', 'ultime', 'news', 'approfondimenti', 'dedicati', 'gestione', 'rischio', 'continua', 'assiteca', 'primo', 'gruppo', 'italiano', 'mercato', 'brokeraggio', 'assicurativo', 'consulenza', 'gestione', 'rischio', 'divisioni', 'speciali', 'affinity', 'small', 'business', 'assiteca', 'agricoltura', 'cauzioni', 'fideiussioni', 'crediti', 'commerciali', 'employee', 'benefits', 'energie', 'rinnovabili', 'internazionale', 'pubblica', 'amministrazione', 'costruzioni', 'infrastrutture', 'tecnica', 'trasporti', 'motor', 'responsabilità', 'sociale', "l'attenzione", 'confronti', 'collettività,', 'cultura,', 'territorio', 'sociale', 'caratterizza', 'sempre', "l'attività", 'assiteca.', 'comportamento', 'equo', 'giusto,', 'conto', "dell'impatto", 'decisioni', 'strategie', 'adottate', '…', 'read', 'servizi', 'consulenza', 'offrire', 'gestione', 'integrata', 'rischi', 'attraverso', 'metodologia', 'lavoro', 'coniuga', 'consulenza', 'intermediazione', 'assicurativa', 'consente', 'costruire', 'efficace', 'sistema', 'controllo', 'utile', 'prevenire,', 'mitigare', 'proteggere', "l'azienda.i", '…', 'read', 'soluzioni', 'assicurative', 'read', 'assiteca', 'spa', 'palazzo', 'assiteca', 'via', 'g.', 'sigieri', '14', '–', '20135', 'milano', 'tel.', '02.54679.1', '–', 'fax', '02.54679.350', 'p.iva/codice', 'fiscale', 'numero', 'd’iscrizione:', '09743130156', 'registro', 'imprese', 'milano', 'iscritta', 'numero', 'repertorio', 'economico', 'amministrativo', '1313138', 'capitale', 'sociale', '€', '7.617.193,51', 'i.v.', 'iscritta', 'r.u.i.', 'sezione', 'b', 'n.', '114899', '16/04/2007', 'copyright', '©', '2004-2020', 'assiteca', 'spa', 'siamo:', 'indirizzi', 'contatti', 'codice', 'assicurazioni', 'dati', 'societari', 'data', 'protection', 'policy', 'cookie', 'policy', 'segnala', 'reclamo', 'utilizziamo', 'cookie', 'essere', 'sicuri', 'possa', 'avere', 'migliore', 'esperienza', 'sito.', 'puoi', 'consultare', 'policy', "sull'utilizzo", 'cookie', 'qualsiasi', 'momento', 'cliccando', 'bottone', 'sotto', 'footer', 'sito,', 'troverai', 'istruzioni', 'disattivarli.', 'utilizamos', 'cookies', 'propias', 'terceros', 'analizar', 'servicios', 'mostrarte', 'publicidad' ...
# assiteca - grande broker assicurativo italiano menu sceglierci servizi consulenza rischi operativi rischi compliance rischi finanziari rischi strategici soluzioni assicurative soluzioni assicurative rischi operativi soluzioni assicurative rischi compliance soluzioni assicurative rischi finanziari soluzioni assicurative rischi strategici divisioni tecnica trasporti motor insurtech assiteca agricoltura energie rinnovabili crediti commerciali enti pubblici sanità employee benefit welfare affinity small business internazionale costruzioni infrastrutture cauzioni fideiussioni academy iniziative blog investor relations stampa contatti l’unica realtà servizi professionali creata assistere aziende gestione integrata rischi d’impresa gestione online clienti assiteca academy clicca scopri report sostenibilità clicca scopri scarica app assiteca gestione sinistri clicca scopri assiteca primo broker assicurativo italiano quotato borsa clicca scopri contattaci clicca scopri blog clicca scopri siamoassiteca grande broker assicurativo italiano. luglio 2015 primo broker quotato borsa italiana - segmento aim italia. continua assitecaassiteca arricchisce l’attività tradizionale brokeraggio assicurativo specifici servizi consulenza continua soluzioni prodotti esclusivi innovativi, divisioni specialistiche competenze specifiche particolari aree rischio. continua leggi blogscopri ultime news approfondimenti dedicati gestione rischio continua assiteca primo gruppo italiano mercato brokeraggio assicurativo consulenza gestione rischio divisioni speciali affinity small business assiteca agricoltura cauzioni fideiussioni crediti commerciali employee benefits energie rinnovabili internazionale pubblica amministrazione costruzioni infrastrutture tecnica trasporti motor responsabilità sociale l'attenzione confronti collettività, cultura, territorio sociale caratterizza sempre l'attività assiteca. comportamento equo giusto, conto dell'impatto decisioni strategie adottate … read servizi consulenza offrire gestione integrata rischi attraverso metodologia lavoro coniuga consulenza intermediazione assicurativa consente costruire efficace sistema controllo utile prevenire, mitigare proteggere l'azienda.i … read soluzioni assicurative read assiteca spa palazzo assiteca via g. sigieri 14 – 20135 milano tel. 02.54679.1 – fax 02.54679.350 p.iva/codice fiscale numero d’iscrizione: 09743130156 registro imprese milano iscritta numero repertorio economico amministrativo 1313138 capitale sociale € 7.617.193,51 i.v. iscritta r.u.i. sezione b n. 114899 16/04/2007 copyright © 2004-2020 assiteca spa siamo: indirizzi contatti codice assicurazioni dati societari data protection policy cookie policy segnala reclamo utilizziamo cookie essere sicuri possa avere migliore esperienza sito. puoi consultare policy sull'utilizzo cookie qualsiasi momento cliccando bottone sotto footer sito, troverai istruzioni disattivarli. utilizamos cookies propias terceros analizar servicios mostrarte publicidad relacionados preferencias, base perfil elaborado partir hábitos navegación. puedes obtener información política cookies aquí. okno - refusecookie policy
# numero di parole: 354
# numero di occorenze: 14
# percentuale: 3.954802259887006

# %%
from googleapi import google
num_page = 3
search_results = google.search("assiteca", num_page)
""""
o=0;
for i in search_results:
    print("#"+str(o)+" ", i.name ,"\n")
    print("#"+str(o)+" "+ i.description +"\n")
    o=o+1
"""
for i in range(4):
    print("#####################################à")
    print(search_results[i].name,"\n")
    print(search_results[i].link,"\n")
    print(search_results[i].description,"\n")
# Out:
# #####################################à
# ASSITECA - il più grande broker assicurativo italianowww.assiteca.it
#
# https://www.assiteca.it/
#
# ASSITECA è il più grande broker assicurativo italiano e offre servizi professionali e consulenza sulla gestione integrata dei rischi aziendali.
#
# #####################################à
# ASSITECA | LinkedInit.linkedin.com › company › assiteca
#
# https://it.linkedin.com/company/assiteca
#
# ASSITECA | 8.394 follower su LinkedIn | Primo gruppo italiano nel mercato del brokeraggio assicurativo e nella consulenza sulla gestione dei rischi d'impresa.
#
# #####################################à
# Assiteca SpA Internazionale Di Brokeraggio Assicurativo ...www.bloomberg.com › profile › company › ASSI:IM
#
# https://www.bloomberg.com/profile/company/ASSI:IM
#
# Assiteca Spa Internazionale Di Brokeraggio Assicurativo provides insurance agent and broker services for a range of insurance types. The Company has offices ...
#
# #####################################à
# ASSI:BrsaItaliana Stock Quote - Assiteca SpA Internazionale ...www.bloomberg.com › quote › ASSI:IM
#
# https://www.bloomberg.com/quote/ASSI:IM
#
# Stock analysis for Assiteca SpA Internazionale Di Brokeraggio Assicurativo (ASSI:BrsaItaliana) including stock price, stock chart, company news, key statistics, ...

# %%
from urllib.parse import urlencode
from fake_useragent import UserAgent
import time
'''
def _filter_link(link):

#Filter links found in the Google result pages HTML code.
    #Returns None if the link doesn't yield a valid result.

    print("sono nel filter link")
    try:
        # Valid results are absolute URLs not pointing to a Google domain
        # like images.google.com or googleusercontent.com
        o = urlparse(link, 'http')
        # link type-1
        # >>> "https://www.gitbook.com/book/ljalphabeta/python-"
        if o.netloc and 'google' not in o.netloc:
            return link
        # link type-2
        # >>> "http://www.google.com/url?url=http://python.jobbole.com/84108/&rct=j&frm=1&q=&esrc=s&sa=U&ved=0ahUKEwj3quDH-Y7UAhWG6oMKHdQ-BQMQFggUMAA&usg=AFQjCNHPws5Buru5Z71wooRLHT6mpvnZlA"
        if o.netloc and o.path.startswith('/url'):
            try:
                link = parse_qs(o.query)['url'][0]
                o = urlparse(link, 'http')
                if o.netloc and 'google' not in o.netloc:
                    return link
            except KeyError:
                pass
        # Decode hidden URLs.
        if link.startswith('/url?'):
            try:
                # link type-3
                # >>> "/url?q=http://python.jobbole.com/84108/&sa=U&ved=0ahUKEwjFw6Txg4_UAhVI5IMKHfqVAykQFggUMAA&usg=AFQjCNFOTLpmpfqctpIn0sAfaj5U5gAU9A"
                link = parse_qs(o.query)['q'][0]
                # Valid results are absolute URLs not pointing to a Google domain
                # like images.google.com or googleusercontent.com
                o = urlparse(link, 'http')
                if o.netloc and 'google' not in o.netloc:
                    return link
            except KeyError:
                # link type-4
                # >>> "/url?url=https://machine-learning-python.kspax.io/&rct=j&frm=1&q=&esrc=s&sa=U&ved=0ahUKEwj3quDH-Y7UAhWG6oMKHdQ-BQMQFggfMAI&usg=AFQjCNEfkUI0RP_RlwD3eI22rSfqbYM_nA"
                link = parse_qs(o.query)['url'][0]
                o = urlparse(link, 'http')
                if o.netloc and 'google' not in o.netloc:
                    return link

    # Otherwise, or on error, return None.
    except Exception:
        pass
    return None
'''


def _get_link(li):
    """Return external link from a search."""
    try:
        a = li.find("a")
        link = a["href"]
    except Exception:
        return None
    return _filter_link(link)

def _get_search_url(query, page=0, per_page=10, lang='en', area='com', ncr=False, time_period=False, sort_by_date=False):
    # note: num per page might not be supported by google anymore (because of
    # google instant)

    params = {
        'nl': lang,
        'q': query.encode('utf8'),
        'start': page * per_page,
        'num': per_page
    }

    time_mapping = {
        'hour': 'qdr:h',
        'week': 'qdr:w',
        'month': 'qdr:m',
        'year': 'qdr:y'
    }


    tbs_param = []
    # Set time period for query if given
    if time_period and time_period in time_mapping:
        tbs_param.append(time_mapping[time_period])

    if sort_by_date:
        tbs_param.append('sbd:1')
    params['tbs'] = ','.join(tbs_param)

    # This will allow to search Google with No Country Redirect
    if ncr:
        params['gl'] = 'us' # Geographic Location: US
        params['pws'] = '0' # 'pws' = '0' disables personalised search
        params['gws_rd'] = 'cr' # Google Web Server ReDirect: CountRy.

    params = urlencode(params)

    url = u"https://www.google.com/search?" + params

    
    # what I found useful.
    https = int(time.time()) % 2 == 0
    bare_url = u"https://www.google.com/search?" if https else u"http://www.google.com/search?"
    url = bare_url + params

    # return u"http://www.google.com/search?hl=%s&q=%s&start=%i&num=%i" %
    # (lang, normalize_query(query), page * per_page, per_page)
    if not ncr:
        if area == 'com':
            url = u"http://www.google.com/search?"
        elif area == 'is':
            url = 'http://www.google.is/search?'
        elif area == 'it':
            url = 'http://www.google.dk/search?'
        else:
            raise AreaError('invalid  name,  no area found')
        url += params
    return url


def get_html(url):
    ua = UserAgent()
    header = ua.random

    try:
        request = urllib.request.Request(url)
        request.add_header("User-Agent", header)
        html = urllib.request.urlopen(request).read()
        return html
    except urllib.error.HTTPError as e:
        print("Error accessing:", url)
        print(e)
        if e.code == 503 and 'CaptchaRedirect' in e.read():
            print("Google is requiring a Captcha. "
                  "For more information check: 'https://support.google.com/websearch/answer/86640'")
        if e.code == 503:
            sys.exit("503 Error: service is currently unavailable. Program will exit.")
        return None
    except Exception as e:
        print("Error accessing:", url)
        print(e)
        return None
    
def _get_name(li):
    """Return the name of a google search."""
    
    a = li.find('span')
    #a = li.find('a')
    
    if a is not None:
        return a.text.strip()
    return None

def _get_link(li):
    """Return external link from a search."""
    try:
        a = li.find("a")
        link = a["href"]
        
    except Exception:
        return None
    
    return link

def _get_description(li):
    """Return the description of a google search.
    TODO: There are some text encoding problems to resolve."""
    
    sdiv = li.find("div", attrs={"class": "IsZvec"})
    if sdiv:
        
        stspan = sdiv.find("span", attrs={"class": "aCOpRe"})
        
        if stspan is not None:
            return stspan.text.strip()
    else:
        return None


def search(query, pages=1, lang='en', area='com', ncr=False, void=True, time_period=False, sort_by_date=False, first_page=0):
    """Returns a list of GoogleResult.
    Args:
        query: String to search in google.
        pages: Number of pages where results must be taken.
        area : Area of google homepages.
        first_page : First page.
    TODO: add support to get the google results.
    Returns:
        A GoogleResult object."""

    results = []
    for i in range(first_page, first_page + pages):
        url = _get_search_url(query, i, lang=lang, area=area, ncr=ncr, time_period=time_period, sort_by_date=sort_by_date)
        
        html = get_html(url)
        #print(html)

        if html:
            soup = BeautifulSoup(html, "html.parser")
            divs = soup.findAll("div", attrs={"class": "g"})
            

            #results_div = soup.find("div", attrs={"id": "resultStats"})
            #number_of_results = _get_number_of_results(results_div)

            j = 0
            for li in divs:
                #res = GoogleResult()

                #res.page = i
                #res.index = j
                

                name = _get_name(li)
                link = _get_link(li)
                #google_link =_get_google_link(li)
                
                description = _get_description(li)
                                
                if void is True:
                    if description is None:
                        continue
                print("\n"+"##########################"+"\n")
                print("TITOLO: "+name)
                print("LINK: "+link)
                print("DESCRIZIONE: "+description)
                
                #results.append(res)
                #print(results.append(res))
                j += 1
    return results
num_pag=3
search("assiteca spa",num_pag)
# Out:
# ##########################
#
# TITOLO: ASSITECA - il più grande broker assicurativo italiano
# LINK: https://www.assiteca.it/
# DESCRIZIONE: ASSITECA è il più grande broker assicurativo italiano e offre servizi professionali e consulenza sulla gestione integrata dei rischi aziendali.
#
# ##########################
#
# TITOLO: Assiteca S.p.a. Internazionale di Brokeraggio Assicurativo
# LINK: https://www.paginegialle.it/milano-mi/assicurazioni/assiteca
# DESCRIZIONE: Assiteca S.p.a. Internazionale di Brokeraggio Assicurativo a Milano (MI) - Assicurazioni - brokers: Su PagineGialle trovi numero, indirizzo e altre info.
#
# ##########################
#
# TITOLO: assiteca spa internazionale di brokeraggio assicurativo in ...
# LINK: https://www.reportaziende.it/assiteca_spa_internazionale_di_brokeraggio_assicurativo
# DESCRIZIONE: Visualizza GRATIS il fatturato e l'utile/perdita di ASSITECA SPA INTERNAZIONALE DI BROKERAGGIO ASSICURATIVO IN FORMA ABBREVIATA ASSITECA ...
#
# ##########################
#
# TITOLO: Assiteca SpA Internazionale Di Brokeraggio Assicurativo ...
# LINK: https://www.bloomberg.com/profile/company/ASSI:IM
# DESCRIZIONE: Assiteca Spa Internazionale Di Brokeraggio Assicurativo provides insurance agent and broker services for a range of insurance types. The Company has offices ...
#
# ##########################
#
# TITOLO: Assiteca SpA - IT0001012639 - MF AIM Italia - Milano Finanza
# LINK: https://aimnews.milanofinanza.it/scheda-azienda/assiteca-IT0001012639
# DESCRIZIONE: Assiteca è il più grande broker assicurativo italiano: svolge attività di intermediazione assicurativa, consulenza e analisi tecnica dei rischi aziendali, a ...
#
# ##########################
#
# TITOLO: Assiteca S.p.A. | Camera di Commercio Italo Cinese
# LINK: https://www.china-italy.com/it/socio/assiteca-spa
# DESCRIZIONE: Assiteca S.p.A.. Presentazione: Assiteca è il primo gruppo italiano nel mercato del brokeraggio assicurativo. Da luglio 2015 è quotata alla Borsa Italiana. La sua ...
#
# ##########################
#
# TITOLO: assiteca spa internazionale di brokeraggio ... - LinkedIn
# LINK: https://www.linkedin.com/company/assiteca-spa-internazionale-di-brokeraggio-assicurativo-in-forma-abbreviata-assiteca-s.p.a.
# DESCRIZIONE: ASSITECA SPA INTERNAZIONALE DI BROKERAGGIO ASSICURATIVO IN FORMA ABBREVIATA ASSITECA S.P.A. | 75 followers on LinkedIn | MEDIAZIONE ...
#
# ##########################
#
# TITOLO: Prezzo azione ASSI | Assiteca SpA Internazionale - Investing ...
# LINK: https://it.investing.com/equities/assiteca-spa-internazionale
# DESCRIZIONE: Panoramica sull'azione Assiteca SpA Internazionale (ASSI) con prezzo, grafici, sentimento, analisi tecniche, cronologia del prezzo del titolo, report e altro ...
#
# ##########################
#
# TITOLO: Profilo Assiteca SpA Internazionale (ASSI) - Investing.com
# LINK: https://it.investing.com/equities/assiteca-spa-internazionale-company-profile
# DESCRIZIONE: Profilo approfondito di Assiteca SpA Internazionale, con le informazioni di contatto e una panoramica sull'attività dell'azienda e sulla sua gestione.
#
# ##########################
#
# TITOLO: ASSITECA perfeziona il progetto di fusione della controllata ...
# LINK: https://www.trend-online.com/ansa/assiteca-perfeziona-il-progetto-di-fusione-della-controllata-arena-broker-387038/
# DESCRIZIONE: 13 lug 2020 — E' stato sottoscritto oggi l'atto di fusioneper incorporazione della controllata Arena Broker S.r.l. nella controllante totalitaria ASSITECA S.p.A., ...
#
# ##########################
#
# TITOLO: Assiteca Spa Archivi Assinews.it
# LINK: https://www.assinews.it/tag/assiteca-spa/
# DESCRIZIONE: Il Consiglio di Amministrazione di ASSITECA S.p.A ha deliberato di procedere all'integrazione, mediante fusione per incorporazione, della società controllata ...
#
# ##########################
#
# TITOLO: Aziende - ASSITECA S.p - Confindustria Chieti Pescara
# LINK: https://confindustriachpe.it/imprese/tutte-le-imprese/4045-assiteca-spa
# DESCRIZIONE: ASSITECA S.p.a. Confindustria Chieti Pescara - Associazione degli Industriali delle provincie di Chieti e Pescara - Sito ufficiale.
#
# ##########################
#
# TITOLO: ASSITECA acquista LENZA BROKER ASSICURAZIONI e ...
# LINK: https://www.investireoggi.it/finanza-borsa/news/assiteca-acquista-lenza-broker-assicurazioni-e-consolida-la-sua-presenza-in-campania/
# DESCRIZIONE: 29 mag 2020 — ASSITECA S.p.A., il più grande broker assicurativo italiano leader nella gestione integrata dei rischi di impresa, quotato all'AIM di Borsa ...
#
# ##########################
#
# TITOLO: Assiteca Spa Internazionale Di Brokeraggio Assicurativo ...
# LINK: https://it.kompass.com/c/assiteca-spa-internazionale-di-brokeraggio-assicurativo/it0026540/
# DESCRIZIONE: 14 feb 2020 — Natura, Sede centrale. Anno di iscrizione, 1989. Forma giuridica, SOCIETA' PER AZIONI. Attività (ATE07), Attività di agenti e mediatori di ...
#
# ##########################
#
# TITOLO: Assiteca | Asefi Brokers
# LINK: https://www.asefibrokers.com/tag/assiteca
# DESCRIZIONE: Il Consiglio di Amministrazione di Assiteca Spa, il più grande broker assicurativo italiano leader nella consulenza per la gestione integrata dei rischi di impresa ...
#
# ##########################
#
# TITOLO: Assiteca chiude l'aumento di capitale riservato a Tikehau, che ...
# LINK: https://bebeez.it/2019/11/06/assiteca-chiude-laumento-capitale-riservato-tikehau-compra-2343-lucca-si-diluisce-al-6038/
# DESCRIZIONE: 6 nov 2019 — Lucca si diluisce al 60,38%. assiteca Tikehau Capital ha rilevato il 23,43% di Assiteca spa, sottoscrivendo un aumento di capitale riservato per 25 ...
#
# ##########################
#
# TITOLO: Azienda: ASSITECA-SPA - Windpress
# LINK: https://www.windpress.info/it/aziende-comunicatori/azienda/33338/ASSITECA-SPA
# DESCRIZIONE: Da 20 anni il marchio Mediaddress® è il punto di riferimento per migliorare l'organizzazione dell'Ufficio Stampa. E' la più grande piattaforma web per gestire e ...
#
# ##########################
#
# TITOLO: Assiteca S.p.A.: 20.01.2020 - ore 14:39 - Calendario eventi ...
# LINK: https://www.moneycontroller.it/dettaglio-mynews/20-01-2020-ore-14-39-calendario-eventi-societari-assiteca-635392
# DESCRIZIONE: 20 gen 2020 — Comunicato stampa ASSITECA: Calendario eventi societari Milano, 20 gennaio 2020 - Assiteca S.p.A., il primo gruppo italiano nel mercato del ...
#
# ##########################
#
# TITOLO: Azienda: assiteca-spa.html - Windpress
# LINK: https://www.windpress.info/it/aziende-comunicatori/azienda/33338/assiteca-spa.html
# DESCRIZIONE: Da 20 anni il marchio Mediaddress® è il punto di riferimento per migliorare l'organizzazione dell'Ufficio Stampa. E' la più grande piattaforma web per gestire e ...
#
# ##########################
#
# TITOLO: Assiteca approva il bilancio al 30 giugno: ricavi in crescita del ...
# LINK: https://www.economymag.it/news/2020/09/30/news/assiteca-approva-il-bilancio-al-30-giugno-ricavi-in-crescita-del-14-22428/
# DESCRIZIONE: 30 set 2020 — Il Consiglio di Amministrazione di ASSITECA S.p.A., il più grande broker assicurativo italiano leader nella consulenza per la gestione integrata ...
#
# ##########################
#
# TITOLO: Azioni Assiteca SpA Internazionale di Brokeraggio ... - Money.it
# LINK: https://www.money.it/+Assiteca-SpA-Internazionale-di-Brokeraggio-Assicurativo-quotazione+
# DESCRIZIONE: Quotazione azioni Assiteca SpA Internazionale di Brokeraggio Assicurativo con grafico prezzi tempo reale , dati fondamentali, analisi e ultime notizie.
#
# ##########################
#
# TITOLO: ASSITECA S.p.A. acquista il 100% di ARENA BROKER S.r.l. e ...
# LINK: https://ilbroker.it/2019/11/20/assiteca-s-p-a-acquista-il-100-di-arena-broker-s-r-l-e-diventa-il-primo-broker-assicurativo-nel-nord-est/
# DESCRIZIONE: 20 nov 2019 — ASSITECA S.p.A., il maggior broker assicurativo italiano leader nella consulenza per la gestione integrata dei rischi di impresa e quotato ...
#
# ##########################
#
# TITOLO: Bilancio in crescita per Assiteca spa - Investire
# LINK: https://www.investiremag.it/investire/2019/10/01/news/bilancio-in-crescita-per-assiteca-spa-6549/
# DESCRIZIONE: 1 ott 2019 — Bilancio in crescita per Assiteca spa. 1 Ottobre 2019. In attesa dell'ingresso di Tikehau nel capitale, il broker assicurativo ha approvato il nuovo ...
#
# ##########################
#
# TITOLO: LUCCA, PATRON DI ASSITECA: «COSI' CI SIAMO ...
# LINK: https://www.tuttointermediari.it/lucca-patron-di-assiteca-cosi-ci-siamo-trasformati-in-consultative-broker-futuro-abbiamo-un-obiettivo-da-raggiungere/
# DESCRIZIONE: 10 giu 2019 — ... brokeraggio assicurativo: Assiteca spa, della quale ha assunto la carica di amministratore delegato e, dal 1992, anche quella di presidente.
#
# ##########################
#
# TITOLO: Assiteca, fusione di due controllate per il broker | L'Arena
# LINK: https://www.larena.it/argomenti/economia/assiteca-fusionedi-due-controllateper-il-broker-1.5796269
# DESCRIZIONE: 27 giu 2017 — lli & Courtman Insurance brokers spa e C.d.m. Insurance brokers srl nella controllante totalitaria Assiteca spa, il broker assicurativo italiano ...
#
# ##########################
#
# TITOLO: Assiteca Spa acquisisce l'80% di Assita Spa « LMF ...
# LINK: https://www.lamiafinanza.it/2019/07/assiteca-spa-acquisisce-l-80-di-assita-spa/
# DESCRIZIONE: 31 lug 2019 — ASSITECA S.p.A., il più grande broker assicurativo italiano indipendente quotato al mercato AIM di Borsa Italiana, ha sottoscritto in data 30 ...
#
# ##########################
#
# TITOLO: Assiteca spa | Regione Abruzzo
# LINK: https://www.regione.abruzzo.it/content/assiteca-spa
# DESCRIZIONE: Assiteca spa. Pubblicato: 26 Aprile 2018. Ultimo aggiornamento: 26 Aprile 2018. Codice fiscale: 09743130156. Webmail regionale · Elenco siti Tematici · Servizi ...
# []

# %%
#parsare con lxml
import urllib
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "https://www.assiteca.it/"
html = urlopen(url).read()

soup = BeautifulSoup(html, "lxml")
for junk in soup(["script", "style"]):
    junk.extract()
    text = soup.get_text()
    #print(text)

# %%
import requests
# !pip3 install requests[security]
import string
import urllib
import collections
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk import word_tokenize, pos_tag, pos_tag_sents
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
stop = stopwords.words('english')
# %matplotlib inline
import spacy
from spacy import displacy
from collections import Counter
#import en_core_web_sm
#nlp = en_core_web_sm.load()
import itertools as it
import networkx as nx
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
! pip3 install pyLDAvis
import pyLDAvis.gensim  
import matplotlib.pyplot as plt
# %matplotlib inline
import pyLDAvis.sklearn
# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
import time
from time import sleep
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}
# Out:
# Requirement already satisfied: requests[security] in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from requests[security]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from requests[security]) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from requests[security]) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from requests[security]) (3.0.4)
# Requirement already satisfied: cryptography>=1.3.4; extra == "security" in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from requests[security]) (3.1.1)
# Requirement already satisfied: pyOpenSSL>=0.14; extra == "security" in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from requests[security]) (19.1.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from cryptography>=1.3.4; extra == "security"->requests[security]) (1.14.3)
# Requirement already satisfied: six>=1.4.1 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from cryptography>=1.3.4; extra == "security"->requests[security]) (1.15.0)
# Requirement already satisfied: pycparser in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.3.4; extra == "security"->requests[security]) (2.20)
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/riccardo/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/riccardo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: pyLDAvis in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (2.1.2)
# Requirement already satisfied: future in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: numexpr in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (2.7.1)
# Requirement already satisfied: pandas>=0.17.0 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (1.1.3)
# Requirement already satisfied: jinja2>=2.7.2 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (2.11.2)
# Requirement already satisfied: numpy>=1.9.2 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (1.19.2)
# Requirement already satisfied: joblib>=0.8.4 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (0.17.0)
# Requirement already satisfied: wheel>=0.23.0 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (0.35.1)
# Requirement already satisfied: pytest in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (6.1.1)
# Requirement already satisfied: funcy in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (1.15)
# Requirement already satisfied: scipy>=0.18.0 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pyLDAvis) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pandas>=0.17.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pandas>=0.17.0->pyLDAvis) (2020.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pytest->pyLDAvis) (1.9.0)
# Requirement already satisfied: toml in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pytest->pyLDAvis) (0.10.1)
# Requirement already satisfied: packaging in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pytest->pyLDAvis) (20.4)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pytest->pyLDAvis) (0.13.1)
# Requirement already satisfied: iniconfig in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pytest->pyLDAvis) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from pytest->pyLDAvis) (20.2.0)
# Requirement already satisfied: six>=1.5 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/riccardo/Scrivania/doyle/lib/python3.8/site-packages (from packaging->pytest->pyLDAvis) (2.4.7)

# %%
base_url = "https://www.google.co.uk/search"
queries = ["assiteca"]
serp_queries = []
serp_urls = []
clean_links = []
links = []
serp_titles = []
serp_descriptions = []

for q in queries:
    query = urllib.parse.quote_plus(q)
    serp_queries.append(query)

for q in serp_queries:
    url = "{base_url}?q={query}&num={num}&cr={serp_country}".format(base_url=base_url, query=q, num="10", serp_country="GB")
    serp_urls.append(url)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    result_div = soup.find_all('div', attrs = {'class': 'ZINbbc'})
    for r in result_div:
        # Checks if each element is present, else, raise exception
        try:
            link = r.find('a', href = True)
            title = r.find('div', attrs={'class':'vvjwJb'}).get_text()
            description = r.find('div', attrs={'class':'s3v9rd'}).get_text()
            # Check to make sure everything is present before appending
            if link != '' and title != '' and description != '': 
                links.append(link['href'])
                serp_titles.append(title)
                serp_descriptions.append(description)
        # Next loop if one element is not present
        except:
            continue
    to_remove = []
    for i, l in enumerate(links):
        clean = re.search('\/url\?q\=(.*)\&sa',l)

        # Anything that doesn't fit the above pattern will be removed
        if clean is None:
            to_remove.append(i)
            continue
        clean_links.append(clean.group(1))
        #print(clean_links)

dedupe_clean_links = list(dict.fromkeys(clean_links))

# %%
paragraphs = []
titles = []
scraped_content = []
scraped_titles = []
for url in dedupe_clean_links:
        #time.sleep(0.01)
        response = requests.get(url, time.sleep(2)) #headers=headers
        soup2 = BeautifulSoup(response.content, "html.parser")
        paragraphs = soup2.find_all('p')
        titles = soup2.find_all(re.compile('^h[1-4]$'))
        i=0
        for paragraph in paragraphs:
            paragraphs = [paragraph.text]
            paragraphs = paragraph.get_text()
            #print("# "+str(i)+" "+paragraphs)
            i=i+1
            scraped_content.append(paragraphs)
        
        for title in titles:
            titles = [title.text]
            titles = title.get_text()
            scraped_titles.append(titles)
scraped_content = list(map(str.strip, scraped_content))

scraped_titles = list(map(str.strip, scraped_titles))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-063e13a4ad14> in <module>
#       3 scraped_content = []
#       4 scraped_titles = []
# ----> 5 for url in dedupe_clean_links:
#       6         #time.sleep(0.01)
#       7         response = requests.get(url, time.sleep(2)) #headers=headers
#
# NameError: name 'dedupe_clean_links' is not defined

# %%
url = "https://www.assiteca.it/"
html = urlopen(url).read()
soup = BeautifulSoup(html)

for script in soup(["script", "style"]):
    script.decompose()



strips = list(soup.stripped_strings)
print(strips[:6])
# Out:
# ['ASSITECA - il più grande broker assicurativo italiano', 'MENU', 'Chi siamo', 'Perché sceglierci', 'Servizi di consulenza', 'Rischi operativi']

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.assiteca.it/'
res = requests.get(url)
html_page = res.content
soup = BeautifulSoup(html_page, 'html.parser')
text = soup.find_all(text=True)

output = ''
blacklist = [
    '[document]',
    'noscript',
    'header',
    'html',
    'meta',
    'head', 
    'input',
    'script',
    'style'
    # there may be more elements you don't want, such as "style", etc.
]

for t in text:
    if t.parent.name not in blacklist:
        output += '{} '.format(t)

print(output)
# Out:
# ASSITECA - il più grande broker assicurativo italiano
#
#
#
#
#
#
#
#
#  MENU
#
#
#
#
#
#
#
#
#  Chi siamo
#  Perché sceglierci
#  Servizi di consulenza
#
#  Rischi operativi
#  Rischi compliance
#  Rischi finanziari
#  Rischi strategici
#
#
#  Soluzioni assicurative
#
#  Soluzioni assicurative per i rischi operativi
#  Soluzioni assicurative per i rischi compliance
#  Soluzioni assicurative per i rischi finanziari
#  Soluzioni assicurative per i rischi strategici
#
#
#  Divisioni
#
#  Tecnica
#  Trasporti
#  Motor
#  Insurtech
#  Assiteca Agricoltura
#  Energie Rinnovabili
#  Crediti Commerciali
#  Enti Pubblici
#  Sanità
#  Employee Benefit e Welfare
#  Affinity e Small Business
#  Internazionale
#  Costruzioni e Infrastrutture
#  Cauzioni e Fideiussioni
#
#
#  Academy e Iniziative
#  Blog
#  Investor Relations
#  Stampa
#  Contatti
#
#
#      L’unica realtà di servizi professionali creata per assistere le aziende nella gestione integrata dei rischi d’impresa
#
#
#
#      gestione online clienti
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Wrapper for slides
#
#
#
#
#
#
#  ASSITECA academy
#
#
#  CLICCA E SCOPRI
#
#
#
#
#
#
#
#
#
#  Report di Sostenibilità
#
#
#   CLICCA E SCOPRI
#
#
#
#
#
#
#
#
#
#  Scarica la app ASSITECA per la gestione dei sinistri
#
#
#  CLICCA E SCOPRI
#
#
#
#
#
#
#
#
#
#  ASSITECA primo broker assicurativo italiano quotato in Borsa
#
#
#  CLICCA E SCOPRI
#
#
#
#
#
#
#
#
#
#  Contattaci
#
#
#  CLICCA E SCOPRI
#
#
#
#
#
#
#
#
#
#
#  BLOG
#
#
#  CLICCA E SCOPRI
#
#
#
#
#
#
#   Controls
#
#
#
#
#
#
#
#
#
#
#  CHI SIAMO Assiteca è il più grande broker assicurativo italiano.  Dal luglio 2015 è il primo broker quotato alla Borsa Italiana - Segmento AIM Italia.
#  Continua
#  PERCHÉ  ASSITECA Assiteca arricchisce l’attività tradizionale di brokeraggio assicurativo con specifici servizi di consulenza
#  CONTINUA
#  LE NOSTRE SOLUZIONI  Prodotti esclusivi e innovativi, divisioni specialistiche con competenze specifiche in particolari aree di rischio.
#  CONTINUA
#  LEGGI IL BLOG Scopri le ultime news e gli approfondimenti dedicati alla gestione del rischio
#  CONTINUA
#  ASSITECA è il primo gruppo italiano nel mercato del brokeraggio assicurativo
# e nella consulenza sulla gestione del rischio
#  LE NOSTRE DIVISIONI SPECIALI
#
#
#  AFFINITY e SMALL BUSINESS
#
#
#
#
#
#  ASSITECA AGRICOLTURA
#
#
#
#
#
#  CAUZIONI E FIDEIUSSIONI
#
#
#
#
#
#  CREDITI COMMERCIALI
#
#
#
#
#
#  EMPLOYEE BENEFITS
#
#
#
#
#
#  ENERGIE RINNOVABILI
#
#
#
#
#
#  INTERNAZIONALE
#
#
#
#
#
#  PUBBLICA AMMINISTRAZIONE
#
#
#
#
#
#  COSTRUZIONI E INFRASTRUTTURE
#
#
#
#
#
#  TECNICA
#
#
#
#
#
#  TRASPORTI
#
#
#
#
#
#  MOTOR
#
#
#
#
#
#
#  Responsabilità Sociale
#  L'attenzione nei confronti della collettività, della cultura, del territorio e del sociale caratterizza da sempre l'attività di ASSITECA. Un comportamento equo e giusto, che tenga conto dell'impatto che le decisioni e le strategie adottate …
#  Read more
#
#
#
#
#
#
#  Servizi di consulenza
#  Offrire una gestione integrata dei rischi attraverso una metodologia di lavoro che coniuga consulenza e intermediazione assicurativa consente di  costruire un efficace sistema di controllo utile a prevenire, mitigare e proteggere l'azienda.I …
#  Read more
#
#
#
#
#
#
#  Soluzioni Assicurative
#
#  Read more
#
#
#
#
#
#
#
#
#
# ASSITECA spa
# Palazzo Assiteca
# via G. Sigieri 14 – 20135 Milano
# Tel. 02.54679.1 – fax 02.54679.350
#
#
#
#  P.IVA/Codice fiscale e numero d’iscrizione: IT 09743130156 del Registro delle Imprese di Milano
# Iscritta con il numero Repertorio Economico Amministrativo 1313138
# Capitale sociale € 7.617.193,51 i.v. Iscritta al R.U.I. sezione B n. 114899 del 16/04/2007
# Copyright © 2004-2020 Assiteca Spa
#
#
#
#  Dove siamo: tutti gli indirizzi
#  Contatti
#  Il codice delle assicurazioni
#  Dati societari
#  Data Protection Policy
#  Cookie policy
#  Segnala un reclamo
#
#    inizio SASSY SOCIAL SHARE
#
#
#  fine SASSY SOCIAL SHARE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   end of .boxed-container
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Cookie Notice plugin v1.3.2 by Digital Factory https://dfactory.eu/
#  Utilizziamo i cookie per essere sicuri che tu possa avere la migliore esperienza sul nostro sito. Puoi consultare la nostra policy sull'utilizzo dei cookie in qualsiasi momento cliccando sul bottone qui sotto o nel footer del sito, dove troverai anche le istruzioni per disattivarli.
# Utilizamos cookies propias y de terceros para analizar nuestros servicios y mostrarte publicidad relacionados con tus preferencias, en base a un perfil elaborado a partir de tus hábitos de navegación. Puedes obtener más información de la política de cookies  aquí.
#  Ok No - Refuse Cookie Policy
#
#   / Cookie Notice plugin

# %%
#MESSO A POSTOOOOO
from bs4 import BeautifulSoup
import urllib
from urllib.parse import urlencode
from fake_useragent import UserAgent
import time



def _get_search_url(query, page=0, per_page=10, lang='en', area='com', ncr=False, time_period=False, sort_by_date=False):
    # il numero di pagine non funziona 

    params = {
        'nl': lang,
        'q': query.encode('utf8'),
        'start': page * per_page,
        'num': per_page
    }

    time_mapping = {
        'hour': 'qdr:h',
        'week': 'qdr:w',
        'month': 'qdr:m',
        'year': 'qdr:y'
    }


    tbs_param = []
    # Settare la data
    if time_period and time_period in time_mapping:
        tbs_param.append(time_mapping[time_period])

    if sort_by_date:
        tbs_param.append('sbd:1')
    params['tbs'] = ','.join(tbs_param)

    # No Country Redirect
    if ncr:
        params['gl'] = 'us' # Geographic Location: US
        params['pws'] = '0' # 'pws' = '0' disables personalised search
        params['gws_rd'] = 'cr' # Google Web Server ReDirect: CountRy.

    params = urlencode(params)

    url = u"https://www.google.com/search?" + params
    print(url)

    
    # what I found useful.
    https = int(time.time()) % 2 == 0
    bare_url = u"https://www.google.com/search?" if https else u"http://www.google.com/search?"
    url = bare_url + params

    if not ncr:
        if area == 'com':
            url = u"http://www.google.com/search?"
        
        elif area == 'it':
            url = 'http://www.google.dk/search?'
        else:
            raise AreaError('invalid  name,  no area found')
        url += params
    return url


def get_html(url):
    ua = UserAgent()
    header = ua.random

    try:
        request = urllib.request.Request(url)
        request.add_header("User-Agent", header)
        html = urllib.request.urlopen(request).read()
        return html
    except urllib.error.HTTPError as e:
        print("Error accessing:", url)
        print(e)
        if e.code == 503 and 'CaptchaRedirect' in e.read():
            print("Google is requiring a Captcha. "
                  "For more information check: 'https://support.google.com/websearch/answer/86640'")
        if e.code == 503:
            sys.exit("503 Error: service is currently unavailable. Program will exit.")
        return None
    except Exception as e:
        print("Error accessing:", url)
        print(e)
        return None
    
def _get_name(li):
    """Return il nome del della pagina."""
    
    a = li.find('span')
    #a = li.find('a')
    
    if a is not None:
        return a.text.strip()
    return None

def _get_link(li):
    """Return il link"""
    try:
        a = li.find("a")
        link = a["href"]
        
    except Exception:
        return None
    
    return link

def _get_description(li):
    """Return la descrizione """
        
    sdiv = li.find("div", attrs={"class": "IsZvec"})
    if sdiv:
        
        stspan = sdiv.find("span", attrs={"class": "aCOpRe"})
        
        if stspan is not None:
            return stspan.text.strip()
    else:
        return None


def search(query, pages=1, lang='en', area='com', ncr=False, void=True, time_period=False, sort_by_date=False, first_page=0):
    """
        query: String to search in google.
        pages: Number of pages where results must be taken.
        area : Area of google homepages.
        first_page : First page.
    """

    results = []
    j = 0
    for i in range(first_page, first_page + pages):
        url = _get_search_url(query, i, lang=lang, area=area, ncr=ncr, time_period=time_period, sort_by_date=sort_by_date)
        
        html = get_html(url)
        #print(html)

        if html:
            soup = BeautifulSoup(html, "html.parser")
            divs = soup.findAll("div", attrs={"class": "g"})

            
            for li in divs:

                name = _get_name(li)
                
                link = _get_link(li)
                
                description = _get_description(li)
                                
                if void is True:
                    if description is None:
                        continue
                j += 1
                print("\n"+"##########################      ",j,"\n")
                print("TITOLO: "+name)
                print("LINK: "+link)
                print("DESCRIZIONE: "+description)
                
                #results.append(res)
                #print(results.append(res))
                
    print("\n"+"*******************************")
    print("SONO STATI TROVATI ",j," RISULTATI")
    print("*******************************")
    
    return results
num_pag=30
search("assiteca spa",num_pag)
# Out:
# https://www.google.com/search?nl=en&q=assiteca+spa&start=0&num=10&tbs=
#
# ##########################       1
#
# TITOLO: ASSITECA - il più grande broker assicurativo italiano
# LINK: https://www.assiteca.it/
# DESCRIZIONE: ASSITECA è il più grande broker assicurativo italiano e offre servizi professionali e consulenza sulla gestione integrata dei rischi aziendali.
#
# ##########################       2
#
# TITOLO: Assiteca S.p.a. Internazionale di Brokeraggio Assicurativo
# LINK: https://www.paginegialle.it/milano-mi/assicurazioni/assiteca
# DESCRIZIONE: Assiteca S.p.a. Internazionale di Brokeraggio Assicurativo a Milano (MI) - Assicurazioni - brokers: Su PagineGialle trovi numero, indirizzo e altre info.
#
# ##########################       3
#
# TITOLO: assiteca spa internazionale di brokeraggio assicurativo in ...
# LINK: https://www.reportaziende.it/assiteca_spa_internazionale_di_brokeraggio_assicurativo
# DESCRIZIONE: Visualizza GRATIS il fatturato e l'utile/perdita di ASSITECA SPA INTERNAZIONALE DI BROKERAGGIO ASSICURATIVO IN FORMA ABBREVIATA ASSITECA ...
#
# ##########################       4
#
# TITOLO: Assiteca SpA Internazionale Di Brokeraggio Assicurativo ...
# LINK: https://www.bloomberg.com/profile/company/ASSI:IM
# DESCRIZIONE: Assiteca Spa Internazionale Di Brokeraggio Assicurativo provides insurance agent and broker services for a range of insurance types. The Company has offices ...
#
# ##########################       5
#
# TITOLO: Assiteca S.p.A. | Camera di Commercio Italo Cinese
# LINK: https://www.china-italy.com/it/socio/assiteca-spa
# DESCRIZIONE: Assiteca S.p.A.. Presentazione: Assiteca è il primo gruppo italiano nel mercato del brokeraggio assicurativo. Da luglio 2015 è quotata alla Borsa Italiana. La sua ...
#
# ##########################       6
#
# TITOLO: assiteca spa internazionale di brokeraggio ... - LinkedIn
# LINK: https://www.linkedin.com/company/assiteca-spa-internazionale-di-brokeraggio-assicurativo-in-forma-abbreviata-assiteca-s.p.a.
# DESCRIZIONE: ASSITECA SPA INTERNAZIONALE DI BROKERAGGIO ASSICURATIVO IN FORMA ABBREVIATA ASSITECA S.P.A. | 75 followers on LinkedIn | MEDIAZIONE ...
#
# ##########################       7
#
# TITOLO: Azioni Assiteca SpA Internazionale | Quotazione ASSI ...
# LINK: https://it.investing.com/equities/assiteca-spa-internazionale
# DESCRIZIONE: Informazioni sulle Azioni di Assiteca SpA Internazionale (ASSI) inclusi Quotazione in tempo reale, Prezzo, Grafici, Analisi tecnica e molto di più su Assiteca SpA ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=10&num=10&tbs=
#
# ##########################       8
#
# TITOLO: ASSITECA perfeziona il progetto di fusione della controllata ...
# LINK: https://www.trend-online.com/ansa/assiteca-perfeziona-il-progetto-di-fusione-della-controllata-arena-broker-387038/
# DESCRIZIONE: 13 lug 2020 — E' stato sottoscritto oggi l'atto di fusioneper incorporazione della controllata Arena Broker S.r.l. nella controllante totalitaria ASSITECA S.p.A., ...
#
# ##########################       9
#
# TITOLO: Azioni Assiteca: quotazioni in tempo reale | IT0001012639 ...
# LINK: https://www.borsaitaliana.it/borsa/azioni/scheda/IT0001012639.html?lang=it
# DESCRIZIONE: Azioni Assiteca in tempo reale (IT0001012639). ... Dealing 15/10/2020 Assiteca S.P.A. (file - 60,12 kb); Specialista Equita Sim; Nomad Integrae SIM S.p.A. ...
#
# ##########################       10
#
# TITOLO: Assiteca Spa Archivi Assinews.it
# LINK: https://www.assinews.it/tag/assiteca-spa/
# DESCRIZIONE: Il Consiglio di Amministrazione di ASSITECA S.p.A ha deliberato di procedere all'integrazione, mediante fusione per incorporazione, della società controllata ...
#
# ##########################       11
#
# TITOLO: Aziende - ASSITECA S.p - Confindustria Chieti Pescara
# LINK: https://confindustriachpe.it/imprese/tutte-le-imprese/4045-assiteca-spa
# DESCRIZIONE: ASSITECA S.p.a. Confindustria Chieti Pescara - Associazione degli Industriali delle provincie di Chieti e Pescara - Sito ufficiale.
#
# ##########################       12
#
# TITOLO: ASSITECA acquista LENZA BROKER ASSICURAZIONI e ...
# LINK: https://www.investireoggi.it/finanza-borsa/news/assiteca-acquista-lenza-broker-assicurazioni-e-consolida-la-sua-presenza-in-campania/
# DESCRIZIONE: 29 mag 2020 — ASSITECA S.p.A., il più grande broker assicurativo italiano leader nella gestione integrata dei rischi di impresa, quotato all'AIM di Borsa ...
#
# ##########################       13
#
# TITOLO: Assiteca Spa Internazionale Di Brokeraggio Assicurativo ...
# LINK: https://it.kompass.com/c/assiteca-spa-internazionale-di-brokeraggio-assicurativo/it0026540/
# DESCRIZIONE: 14 feb 2020 — Natura, Sede centrale. Anno di iscrizione, 1989. Forma giuridica, SOCIETA' PER AZIONI. Attività (ATE07), Attività di agenti e mediatori di ...
#
# ##########################       14
#
# TITOLO: Assiteca chiude l'aumento di capitale riservato a Tikehau, che ...
# LINK: https://bebeez.it/2019/11/06/assiteca-chiude-laumento-capitale-riservato-tikehau-compra-2343-lucca-si-diluisce-al-6038/
# DESCRIZIONE: 6 nov 2019 — Lucca si diluisce al 60,38%. assiteca Tikehau Capital ha rilevato il 23,43% di Assiteca spa, sottoscrivendo un aumento di capitale riservato per 25 ...
#
# ##########################       15
#
# TITOLO: Assiteca | Asefi Brokers
# LINK: https://www.asefibrokers.com/tag/assiteca
# DESCRIZIONE: Il Consiglio di Amministrazione di Assiteca Spa, il più grande broker assicurativo italiano leader nella consulenza per la gestione integrata dei rischi di impresa ...
#
# ##########################       16
#
# TITOLO: Azienda: ASSITECA-SPA - Windpress
# LINK: https://www.windpress.info/it/aziende-comunicatori/azienda/33338/ASSITECA-SPA
# DESCRIZIONE: Da 20 anni il marchio Mediaddress® è il punto di riferimento per migliorare l'organizzazione dell'Ufficio Stampa. E' la più grande piattaforma web per gestire e ...
#
# ##########################       17
#
# TITOLO: assiteca spa - Dettaglio della Ricerca
# LINK: https://servizi.ivass.it/RuirPubblica/DetailResult.faces?id=159994
# DESCRIZIONE: Ragione o denominazione sociale : ASSITECA SPA. Data Iscrizione : 16 aprile 2007. Sede Legale : VIA SIGIERI 14 - 20135 MILANO (MI). Sedi Secondarie : ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=20&num=10&tbs=
#
# ##########################       18
#
# TITOLO: Assiteca SpA - IT0001012639 - MF AIM Italia - Milano Finanza
# LINK: https://aimnews.milanofinanza.it/scheda-azienda/assiteca-IT0001012639
# DESCRIZIONE: Assiteca è il più grande broker assicurativo italiano: svolge attività di intermediazione assicurativa, consulenza e analisi tecnica dei rischi aziendali, a ...
#
# ##########################       19
#
# TITOLO: ASSITECA S.p.A. acquista il 100% di ARENA BROKER S.r.l. e ...
# LINK: https://ilbroker.it/2019/11/20/assiteca-s-p-a-acquista-il-100-di-arena-broker-s-r-l-e-diventa-il-primo-broker-assicurativo-nel-nord-est/
# DESCRIZIONE: 20 nov 2019 — ASSITECA S.p.A., il maggior broker assicurativo italiano leader nella consulenza per la gestione integrata dei rischi di impresa e quotato ...
#
# ##########################       20
#
# TITOLO: Bilancio in crescita per Assiteca spa - Investire
# LINK: https://www.investiremag.it/investire/2019/10/01/news/bilancio-in-crescita-per-assiteca-spa-6549/
# DESCRIZIONE: 1 ott 2019 — Bilancio in crescita per Assiteca spa. 1 Ottobre 2019. In attesa dell'ingresso di Tikehau nel capitale, il broker assicurativo ha approvato il nuovo ...
#
# ##########################       21
#
# TITOLO: LUCCA, PATRON DI ASSITECA: «COSI' CI SIAMO ...
# LINK: https://www.tuttointermediari.it/lucca-patron-di-assiteca-cosi-ci-siamo-trasformati-in-consultative-broker-futuro-abbiamo-un-obiettivo-da-raggiungere/
# DESCRIZIONE: 10 giu 2019 — ... brokeraggio assicurativo: Assiteca spa, della quale ha assunto la carica di amministratore delegato e, dal 1992, anche quella di presidente.
#
# ##########################       22
#
# TITOLO: Assiteca S.p.A.: 30.09.2020 - ore 14:30 - MoneyController
# LINK: https://www.moneycontroller.it/dettaglio-mynews/30-09-2020-ore-14-30-assiteca-ottimi-i-risultati-di-bilancio-confermato-il-dividendo-641312
# DESCRIZIONE: 30 set 2020 — Assiteca S.p.A.: 30.09.2020 - ore 14:30 - ASSITECA: ottimi i risultati di Bilancio, confermato il dividendo.
#
# ##########################       23
#
# TITOLO: ASSITECA ACQUISISCE L'80% DI ASSITA SPA |
# LINK: http://www.assicuriamocibene.it/2019/08/19/assiteca-acquisisce-l80-di-assita-spa/
# DESCRIZIONE: 19 ago 2019 — ASSITECA S.p.A., il più grande broker assicurativo italiano indipendente quotato al mercato AIM di Borsa Italiana, ha sottoscritto in data 30 ...
#
# ##########################       24
#
# TITOLO: ASSITECA SPA » VetrinaImpresa – Confindustria Avellino
# LINK: https://www.confindustria.av.it/members/name/assiteca-spa/
# DESCRIZIONE: Assiteca è una realtà di servizi professionali creata per assistere le aziende nella gestione integrata dei rischi d'impresa. Nata nel 1982, è oggi il più grande ...
#
# ##########################       25
#
# TITOLO: Assiteca, fusione di due controllate per il broker | L'Arena
# LINK: https://www.larena.it/argomenti/economia/assiteca-fusionedi-due-controllateper-il-broker-1.5796269
# DESCRIZIONE: 27 giu 2017 — lli & Courtman Insurance brokers spa e C.d.m. Insurance brokers srl nella controllante totalitaria Assiteca spa, il broker assicurativo italiano ...
#
# ##########################       26
#
# TITOLO: Assiteca Spa acquisisce l'80% di Assita Spa « LMF ...
# LINK: https://www.lamiafinanza.it/2019/07/assiteca-spa-acquisisce-l-80-di-assita-spa/
# DESCRIZIONE: 31 lug 2019 — ASSITECA S.p.A., il più grande broker assicurativo italiano indipendente quotato al mercato AIM di Borsa Italiana, ha sottoscritto in data 30 ...
#
# ##########################       27
#
# TITOLO: Assiteca SIM – Società di Intermediazione Mobiliare
# LINK: http://www.assitecasim.it/
# DESCRIZIONE: 2 apr 2020 — SliderValueInvesting2-Assiteca-Sim ... Intervento di Roberto Russo, Amministratore Delegato di Assiteca SIM a "5 Giorni sui Mercati. Roberto Russo a ... Assiteca SIM Spa | Sede Legale: Viale Majno, 18 | 20129 Milano | Tel.
# https://www.google.com/search?nl=en&q=assiteca+spa&start=30&num=10&tbs=
#
# ##########################       28
#
# TITOLO: Assiteca acquisisce l'80% di Assita spa - Affaritaliani.it
# LINK: http://www.affaritaliani.it/economia/assiteca-acquisisce-80-di-assita-spa-618856.html
# DESCRIZIONE: 31 lug 2019 — ASSITECA S.p.A., il più grande broker assicurativo italiano indipendente quotato al mercato AIM di Borsa Italiana, ha sottoscritto in data 30 ...
#
# ##########################       29
#
# TITOLO: Assiteca spa | Regione Abruzzo
# LINK: https://www.regione.abruzzo.it/content/assiteca-spa
# DESCRIZIONE: Assiteca spa. Pubblicato: 26 Aprile 2018. Ultimo aggiornamento: 26 Aprile 2018. Codice fiscale: 09743130156. Webmail regionale · Elenco siti Tematici · Servizi ...
#
# ##########################       30
#
# TITOLO: Azioni Assiteca SpA Internazionale di Brokeraggio ... - Money.it
# LINK: https://www.money.it/+Assiteca-SpA-Internazionale-di-Brokeraggio-Assicurativo-quotazione+
# DESCRIZIONE: Quotazione azioni Assiteca SpA Internazionale di Brokeraggio Assicurativo con grafico prezzi tempo reale , dati fondamentali, analisi e ultime notizie.
#
# ##########################       31
#
# TITOLO: Assiteca - Consorzio Italiano Biogas
# LINK: https://www.consorziobiogas.it/consorziati/assiteca/
# DESCRIZIONE: ASSITECA spa. Via G. Sigieri ,14 – 20135 Milano. Tel.: 02 54679.1. Fax: 02 55192298. E-mail: energie@assiteca.it. Sito web: www.assiteca.it. Attività. Attività di ...
#
# ##########################       32
#
# TITOLO: Assiteca - ANPAS Associazione Nazionale Pubbliche ...
# LINK: https://www.anpas.org/46-utilita-gen/convenzioni/596-assiteca.html
# DESCRIZIONE: Zurich Connect è il marchio di Zuritel S.p.A., l'assicurazione telefonica e online del gruppo Zurich, gruppo assicurativo dal 1872 sinonimo di esperienza e serietà a ...
#
# ##########################       33
#
# TITOLO: Quotazioni Assiteca SpA | ASSI | Morningstar
# LINK: http://tools.morningstar.it/it/stockreport/default.aspx?SecurityToken=0P00016G2H%5D3%5D0%5DE0WWE%24%24ALL
# DESCRIZIONE: Ultimo prezzo delle azioni di Assiteca SpA da Morningstar con i dividendi, le news, grafici e altro ancora - ASSI, IT0001012639.
#
# ##########################       34
#
# TITOLO: ᐅ Orari Assiteca Spa | Via Principe Amedeo 46, 74123 Taranto
# LINK: https://www.oraridiapertura24.it/filiale/Taranto-Assiteca%2520Spa-1632945Y.html
# DESCRIZIONE: Orari di apertura Assiteca Spa ➤ Via Principe Amedeo 46, 74123 Taranto ☎ Numero di telefono ✓ Indirizzo ✓ Altre offerte nelle vicinanze ✓ Guarda ora!
#
# ##########################       35
#
# TITOLO: Polizza assicurativa per i volontari ASSITECA - csv-padova
# LINK: https://csvpadova.org/polizza-assicurativa-per-i-volontari/
# DESCRIZIONE: https://www.assiteca.it/polizze-le-associazioni-volontariato/. Contatti. Mario Petrucci – Alessio Mangini – Elisabetta Sechi. Assiteca spa – Filiale di Genova
#
# ##########################       36
#
# TITOLO: ASSITECA SpA - SciareMag
# LINK: https://www.sciaremag.it/montagnaonline-azienda/assiteca-spa/
# DESCRIZIONE: ASSITECA SpA. Indirizzo: Via Sigieri 14 20135 Milano Email: assiteca@assiteca.it. Tel.: 0254679418 - FAX: 0254679418. Sito Web: www.assiteca.it
#
# ##########################       37
#
# TITOLO: ASSITECA S.P.A. INTERNAZIONALE DI BROKERAGGIO ...
# LINK: https://www.amministrazionicomunali.it/lombardia/milano/assiteca-spa-internazionale-di-brokeraggio-assicurativo
# DESCRIZIONE: ASSITECA S.P.A. INTERNAZIONALE DI BROKERAGGIO ASSICURATIVO è un azienda presente nel Comune di Milano con sede legale in VIA G. SIGIERI N° ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=40&num=10&tbs=
#
# ##########################       38
#
# TITOLO: Premio Assiteca 2016: Innovazione Digitale
# LINK: http://www.premioassiteca.it/
# DESCRIZIONE: Nella propria attività di consulenza e brokeraggio assicurativo, ASSITECA ha sempre operato nella convinzione che l'impresa ... Assiteca Spa Palazzo Assiteca
#
# ##########################       39
#
# TITOLO: Assiteca S.P.A. 02546791 Via Sigieri Goffredo, 14
# LINK: https://www.inelenco.com/?dir=vedi&id=16342539-privativie&nome=Assiteca%20S.P.A.
# DESCRIZIONE: Dati, Assiteca S.P.A. 02546791 Via Sigieri Goffredo, 14 vedi indirizzo, numero di telefono, cerca CAP, comune, mappa Assiteca S.P.A. 02546791 Via Sigieri ...
#
# ##########################       40
#
# TITOLO: Azioni Assiteca - Analisi Tecnica - Il commento dell'Esperto ...
# LINK: https://www.teleborsa.it/azioni/assiteca-assi-it0001012639-SVQwMDAxMDEyNjM5/analisi?tab=2
# DESCRIZIONE: Analisi Assiteca ASSI - IT0001012639: Il commento dell'Esperto. Analisi tecnica dettagliata, andamento nel tempo, resistenza, analisi fondamentale, prezzo, ...
#
# ##########################       41
#
# TITOLO: Assiteca Napoli Spa, via alla fusione con la "società madre ...
# LINK: https://www.ildenaro.it/assiteca-napoli-spa-via-alla-fusione-con-la-societa-madre/
# DESCRIZIONE: Costituita nel 1986, Assiteca Napoli Spa è oggi una delle società di brokeraggio assicurativo più importanti dell'Italia del sud. Operativa in campo industriale, ...
#
# ##########################       42
#
# TITOLO: Assiteca SIM - FundsPeople
# LINK: https://it.fundspeople.com/companies/assiteca-sim
# DESCRIZIONE: Assiteca SIM nasce nel mese di settembre 2012 grazie al sodalizio tra Alessandro Falciai, Roberto Russo e Assiteca S.p.A., la più grande società di...
#
# ##########################       43
#
# TITOLO: Assiteca, sottoscritto l'aumento di capitale sociale riservato di ...
# LINK: https://www.simplybiz.eu/assiteca-sottoscritto-aumento-capitale-sociale-riservato/
# DESCRIZIONE: 5 nov 2019 — Si è riunita oggi l'assemblea straordinaria e ordinaria degli azionisti di Assiteca s.p.a., broker assicurativo italiano attivo nella consulenza per la ...
#
# ##########################       44
#
# TITOLO: Assiteca acquisisce la totalità del capitale di Assiteca Adriatica ...
# LINK: https://www.pltvbroker.it/2018/07/11/assiteca-acquisisce-la-totalita-del-capitale-di-assiteca-adriatica/
# DESCRIZIONE: 11 lug 2018 — Assiteca S.p.A., il più grande broker assicurativo italiano quotato sul mercato AIM di. Borsa Italiana, ha acquisito in data odierna tramite la ...
#
# ##########################       45
#
# TITOLO: Ideavvocati - Assiteca - - CF Convenzioni
# LINK: http://convenzioni.cassaforense.it/servizi-bancari-e-assicurativi/assicurazioni/rc-professionale-e-infortuni/ideavvocati-assiteca/
# DESCRIZIONE: ... assicurativa Ideavvocati per la copertura assicurativa della responsabilità civile professionale. La gestione del prodotto è affidata al Broker Assiteca Spa.
#
# ##########################       46
#
# TITOLO: Azioni Assiteca SpA Internazionale di Brokeraggio ...
# LINK: https://www.emiliotomasini.it/quotazioni/IT0001012639/azioni-assiteca-spa-internazionale-di-brokeraggio-assicurativo/
# DESCRIZIONE: Azioni Assiteca SpA Internazionale di Brokeraggio Assicurativo - isin IT0001012639: segnali di trading sulle azioni italiane.
#
# ##########################       47
#
# TITOLO: Assiteca - uilcalombardia.it
# LINK: https://uilcalombardia.it/elemento/assiteca/
# DESCRIZIONE: Convenzione Assiteca. Uilca Lombardia offre ai ... UILCA Lombardia - convenzioni Assiteca ... Assiteca SpA – Divisione Affinity e Personal Line Via Lattuada, 25 ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=50&num=10&tbs=
#
# ##########################       48
#
# TITOLO: ASSITECA NEWS - Aisom
# LINK: http://www.aisom.it/assiteca-news/
# DESCRIZIONE: Contatti. ASSITECA Spa Via G. Sigieri, 14 – 20135 Milano www.assiteca.it ...
#
# ##########################       49
#
# TITOLO: Azioni ASSITECA: quotazione, grafico, dati e notizie ...
# LINK: https://www.soldionline.it/quotazioni/dettaglio/IT0001012639.html
# DESCRIZIONE: 1 set 2020 — Quotazione ASSITECA (ISIN IT0001012639): prezzi aggiornati, grafici, dati fondamentali, raccomandazioni e tutte le ultime notizie sul titolo ...
#
# ##########################       50
#
# TITOLO: ASSITECA acquista 6SICURO,primario aggregatore ...
# LINK: https://www.newinsurance.it/assiteca-acquista-6sicuro/
# DESCRIZIONE: 18 feb 2020 — ASSITECA S.p.A., il più grande broker assicurativo italiano quotato al mercato AIM di Borsa Italiana, ha sottoscritto in data 14 febbraio 2020 un ...
#
# ##########################       51
#
# TITOLO: Assiteca - Tikehau - Cross Border
# LINK: http://www.crossborder.website/it/project/assiteca-tikehau/
# DESCRIZIONE: 11 nov 2019 — Assiteca S.p.A. è il primo gruppo italiano nel mercato del brokeraggio assicurativo. Fondata nel 1982, si è quotata alla Borsa Italiana S.p.A. nel ...
#
# ##########################       52
#
# TITOLO: Quotazione Assiteca - IT0001012639 - Borse.it
# LINK: https://www.borse.it/quotazioni/borsa-italiana-azioni/valore/Assiteca-IT0001012639
# DESCRIZIONE: Quotazione del titolo Assiteca IT0001012639 prezzi aggiornati di tutti i titoli italiani ed esteri su borse.it.
#
# ##########################       53
#
# TITOLO: Assiteca, il broker assicurativo si sposta sui servizi di ...
# LINK: https://www.repubblica.it/economia/affari-e-finanza/2017/12/04/news/assiteca_il_broker_assicurativo_si_sposta_sui_servizi_di_consulenza_si_devono_prevenire_i_rischi-182969709/
# DESCRIZIONE: 4 dic 2017 — <p>C 'era una volta Assiteca, un broker assicurativo quotato dal 2015 alla ... ha cambiato nome e ad Assiteca ha aggiunto le parole “Consultative broker”. ... Divisione Stampa Nazionale - GEDI Gruppo Editoriale S.p.A. - P.Iva ...
#
# ##########################       54
#
# TITOLO: ASSITECA SPA - Confindustria Verona - VETRINA delle ...
# LINK: https://vetrina.confindustria.vr.it/development/verona/vetrina.nsf/($linkacross)/37560933DF0EBF8FC1257730003BA337?opendocument&language=IT
# DESCRIZIONE: ASSITECA SPA - FILIALE DI VERONA. Scheda Aziendale. Presentazione Azienda. Assiteca è l'unica realtà di servizi professionali creata per assistere le ...
#
# ##########################       55
#
# TITOLO: ASSITECA S.P.A., Assicurazioni, Brokers di assicurazione ...
# LINK: https://www.europages.it/ASSITECA-SPA/SEAC001084552-001.html
# DESCRIZIONE: Scoprite l'azienda ASSITECA S.P.A. su Europages e contattatela direttamente per avere maggiori informazioni, richiedere un preventivo, ecc.
#
# ##########################       56
#
# TITOLO: ASSITECA ADERISCE A PORDENONE 2020: È UN NUOVO ...
# LINK: https://www.pordenonecalcio.com/2018/12/20/assiteca-aderisce-a-pordenone-2020-e-un-nuovo-socio-neroverde/
# DESCRIZIONE: 20 dic 2018 — Con Assiteca main sponsor il Pordenone ha giocato l'ottavo di finale di ... Il presidente di Assiteca S.p.A. Luciano Lucca afferma: «Entriamo nel ...
#
# ##########################       57
#
# TITOLO: Trova Numeri Assiteca S.P.A. Tel:02546791
# LINK: https://www.trovanumeri.com/?azione=dettagli&id=641603&datab=aziendepb&telefono=Tel:02546791&nome=Assiteca%20S.P.A.
# DESCRIZIONE: Questo sito utilizza cookie, anche di terze parti, per mostrarti pubblicità e servizi in linea con le tue preferenze. Se vuoi saperne di più o negare il consenso a tutti ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=60&num=10&tbs=
#
# ##########################       58
#
# TITOLO: Assiteca SpA Internazionale di Brokeraggio Assicurativo, ASSI ...
# LINK: https://markets.ft.com/data/equities/tearsheet/summary?s=ASSI:MIL
# DESCRIZIONE: Latest Assiteca SpA Internazionale di Brokeraggio Assicurativo (ASSI:MIL) share price with interactive charts, historical prices, comparative analysis, forecasts, ...
#
# ##########################       59
#
# TITOLO: Assiteca SpA - IBN Consultant - Employee Benefit Expertise
# LINK: https://www.internationalbenefits.net/consultant/assiteca-spa/
# DESCRIZIONE: Assiteca SpA. Italy. Assiteca was established in 1982, and is now the largest independent privately held insurance broker in Italy. The company was ...
#
# ##########################       60
#
# TITOLO: Untitled - Comune di Campodoro
# LINK: http://www.comune.campodoro.pd.it/c028018/zf/index.php/bandi-di-gara/bandi-di-gara/allegato/procedura/AT/serialAllegato/7360
# DESCRIZIONE: della Società ASSITECA S.p.A. Internazionale di Brokeraggio Assicurativo in breve ASSITECA S.p.A. sede legale: Milano - Via G. Sigieri nº 14. Ufficio Gare tel.
#
# ##########################       61
#
# TITOLO: Assiteca Spa a Manzano (33044) - Assicurazioni
# LINK: https://www.misterimprese.it/friuli-venezia-giulia/udine/manzano/assicurazioni/918910.html
# DESCRIZIONE: Tutte le Informazioni su Assiteca Spa a Manzano (33044) - Assicurazioni - Indirizzo, Numero di Telefono, CAP, Mappa e Altre Info Utili su MisterImprese!
#
# ##########################       62
#
# TITOLO: Assiteca S.p.a. a Taranto (74100) - Assicurazioni
# LINK: https://www.misterimprese.it/puglia/taranto/taranto/assicurazioni/1871940.html
# DESCRIZIONE: Assiteca S.p.a.. Internazionale Brokeraggio Assicurativo. Indirizzo: Via Duca Degli Abruzzi, 28. CAP: 74100. Città: Taranto (TA). Contatti: 099 4540729.
#
# ##########################       63
#
# TITOLO: ASSI.MI - Assiteca Spa Intrnznl Di Brkrg Ascurtv Profile | Reuters
# LINK: https://www.reuters.com/companies/ASSI.MI
# DESCRIZIONE: Assiteca SpA Internazionale di Brokeraggio Assicurativo is an-Italy-based company that provides products and services. Industry. Insurance (Miscellaneous).
#
# ##########################       64
#
# TITOLO: ASSITECA – Integrae.it
# LINK: https://integrae.it/cms/portfolio-posts/assiteca/
# DESCRIZIONE: In data 23 luglio 2015 Assiteca S.p.A. ha ottenuto l'ammissione delle azioni sul mercato AIM Italia organizzato e gestito da parte di Borsa Italiana. L'inizio delle ...
#
# ##########################       65
#
# TITOLO: Assiteca Spa - Lecco - assicurazioni Viale Dante Alighieri 14 ...
# LINK: http://www.assicuragenzie.com/assicurazioni/19106-assicurazioni-lecco-LC.html
# DESCRIZIONE: Assiteca Spa - Lecco: consulta su Assicuragenzie.com indirizzo, numero telefonico riguardanti l'agenzia di assicurazioni a Lecco. Richiedere un preventivo per ...
#
# ##########################       66
#
# TITOLO: COMUNE DI FONTE - (prov. Treviso)
# LINK: http://www.comune.fonte.tv.it/zf/index.php/trasparenza/index/index/categoria/63/page/77
# DESCRIZIONE: Beneficiario, Atto, Importo, Anno Beneficio, Atti di concessione. ASSITECA S.P.A.. Via G. Sigieri 14 20135 - Milano (MI) CF: 09743130156. PIVA: 09743130156.
#
# ##########################       67
#
# TITOLO: Assiteca Sim: Gambardella nuovo responsabile delle gestioni ...
# LINK: https://www.wallstreetitalia.com/assiteca-sim-gambardella-nuovo-responsabile-delle-gestione-di-portafoglio/
# DESCRIZIONE: 17 lug 2019 — Ad oggi, infatti, oltre ai soci storici Alessandro Falciai, Roberto Russo e Assiteca S.p.A., Assiteca SIM vede la partecipazione di altri quattordici ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=70&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=80&num=10&tbs=
#
# ##########################       68
#
# TITOLO: Assiteca Spa: Tool Veicolo Sicuro
# LINK: https://www.cornerassiteca.it/Logout.aspx
# DESCRIZIONE: Potranno essere inclusi in polizza solo autovetture con uso privato che presentino l'attestato di rischio con 5 annualità più l'anno corrente valorizzati e l'assenza ...
#
# ##########################       69
#
# TITOLO: Tool Veicolo Sicuro - Assiteca Spa
# LINK: https://www.cornerassiteca.it/Registrazione.aspx
# DESCRIZIONE: Veicolo Sicuro - Assiteca Spa P. IVA: 09743130156 ToolCargoNet. Ver. 5.99i del 05/07/2019 (--- ms. 0) IP: 066.249.076.149 ...
#
# ##########################       70
#
# TITOLO: 2017_assiteca_cv_pdf_10619.pdf - Agec
# LINK: https://www.agec.it/sites/default/files/Amministrazione%20trasparente/Consulenti%20e%20collaboratori/2017_assiteca_cv_pdf_10619.pdf
# DESCRIZIONE: Direttore della Divisione Enti Pubblici di Assiteca S.p.A.. Coordinatore Ufficio Tecnico Enti Pubblici e ufficio Gare. Coordinatore del Comitato Tecnico Pubblica ...
#
# ##########################       71
#
# TITOLO: Assiteca spa - Convenzioni Unisin
# LINK: https://www.convenzioniunisin.it/assiteca-spa/
# DESCRIZIONE: 26 mar 2017 — Broker assicurativo. CONVENZIONE ASSITECA UNISIN PRODOTTI ASSICURATIVI A COSTI COMPETITIVI PER ISCRITTI E FAMILIARI ...
#
# ##########################       72
#
# TITOLO: Azioni Assiteca SpA Internazionale di Brokeraggio Assicurativo
# LINK: https://www.riuscireinborsa.it/raccomandazioni-di-borsa/IT0001012639/
# DESCRIZIONE: Created with Highcharts 8.2.0 ISIN: IT0001012639 BOTTOM BOTTOM Jan '20 Oct '19 Apr '20 Jul '20 2020 2 3 1.5 2.5 1.25 1.75 2.25 2.75 3.25 Zoom 1m 3m 6m ...
#
# ##########################       73
#
# TITOLO: Assiteca S.P.A. - Assicurazione a Taranto - Pronto Imprese
# LINK: https://www.prontoimprese.it/taranto/assicurazione/assiteca
# DESCRIZIONE: Assiteca S.P.A.. Internazionale Brokeraggio Assicurativo. Indirizzo: V. Principe Amedeo, 46 - 74100 Taranto. Telefono: 0994540729, 0994534542, 0994596175.
#
# ##########################       74
#
# TITOLO: dm_approvazione_subentro_broker.pdf - Ministero degli Affari ...
# LINK: http://www.esteri.it/mae/amministrazione_aperta/2014/dgcs/dm_approvazione_subentro_broker.pdf
# DESCRIZIONE: che in data 19.11.2013 la società ASSITECA SpA ha notificato al Ministero degli Affari Esteri di aver sottoscritto in data 04.11.2013 un contratto di affitto di ramo ...
#
# ##########################       75
#
# TITOLO: ASSI Stock Price | Assiteca S.p.A. Stock Quote (Italy: Milan ...
# LINK: https://www.marketwatch.com/investing/stock/assi?countrycode=it
# DESCRIZIONE: ASSI | Complete Assiteca S.p.A. stock news by MarketWatch. View real-time stock prices and stock quotes for a full financial overview.
#
# ##########################       76
#
# TITOLO: Assiteca Spa Filiale di Verona Verona - Brokers numero di ...
# LINK: https://www.aziendit.com/aziende/assiteca-spa-filiale-di-verona-verona-via-francia-4
# DESCRIZIONE: Assiteca Spa Filiale di Verona a Verona 37135 - Brokers : Numero di telefono, indirizzo, commenti e recensioni, mappa, foto, video, metodi di pagamento, ...
#
# ##########################       77
#
# TITOLO: ASSITECA S.P.A. : Shareholders Board Members Managers ...
# LINK: https://www.marketscreener.com/quote/stock/ASSITECA-S-P-A-23145655/company/
# DESCRIZIONE: Assiteca SpA Internazionale di Brokeraggio Assicurativo is an-Italy-based company that provides products and services. Sales per Business ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=90&num=10&tbs=
#
# ##########################       78
#
# TITOLO: Nasce la rete di Assiteca sim - Bluerating.com - Bluerating.com
# LINK: https://www.bluerating.com/banche-e-reti/473594/nasce-la-rete-assiteca-sim
# DESCRIZIONE: 4 set 2017 — “saranno collocate dal nostro broker Assiteca Spa che dispone di una rete di oltre 500 professionisti in oltre 20 sedi. Sono in corso di definizione ...
#
# ##########################       79
#
# TITOLO: ASSITECA, Dario Zerboni nominato... - Il Broker Assicurativo ...
# LINK: https://www.facebook.com/il.assicurativo/posts/assiteca-dario-zerboni-nominato-direttore-comunicazione-relazioni-esterne-e-rapp/2345892545699116/
# DESCRIZIONE: 15 gen 2020 — ASSITECA, Dario Zerboni nominato Direttore Comunicazione, Relazioni Esterne e Rapporti Istituzionali - Il Broker.it. ASSITECA S.p.A., primo ...
#
# ##########################       80
#
# TITOLO: Does The Hype Around Assiteca S.p.A.'s (BIT:ASSI) Growth ...
# LINK: https://simplywall.st/stocks/it/insurance/bit-assi/assiteca-shares/news/does-the-hype-around-assiteca-s-p-a-s-bitassi-growth-justify-its-january-share-price/
# DESCRIZIONE: 7 gen 2019 — Assiteca S.p.A. (BIT:ASSI) closed yesterday at €2.4, which left some investors asking whether the high earnings potential can still be justified at ...
#
# ##########################       81
#
# TITOLO: PORDENONE - Assiteca Spa, il maggior broker assicurativo ...
# LINK: https://www.ilgazzettino.it/pay/pordenone_pay/pordenone_assiteca_spa_maggior_broker_assicurativo_italiano_indipendente-1209161.html
# DESCRIZIONE: 25 ago 2015 — PORDENONE - Assiteca Spa, il maggior broker assicurativo italiano indipendente, comunica che Borsa italiana ha ammesso le azioni ...
#
# ##########################       82
#
# TITOLO: ASSITA S.p.A.: ASSICURAZIONI DAL 1981…
# LINK: https://www.assita.com/
# DESCRIZIONE: Dal 1981 è l'unico intermediario ad occuparsi esclusivamente di R.C. Professionale. Da sempre Leader nazionale di riferimento per ORDINI, ASSOCIAZIONI, ...
#
# ##########################       83
#
# TITOLO: Intesa Sanpaolo RBM Salute S.p.A.
# LINK: https://www.intesasanpaolorbmsalute.com/
# DESCRIZIONE: RBM Assicurazione Salute S.p.A. è entrata a far parte del Gruppo Intesa Sanpaolo e ha cambiato la propria denominazione in Intesa Sanpaolo RBM Salute ...
#
# ##########################       84
#
# TITOLO: Nexive Spa Trento
# LINK: http://joak.nuovocesif.it/nexive-spa-trento.html
# DESCRIZIONE: ... italia spa -- gbsapri spa -- consulbrokers -- marsh spa -- aon spa -- union brokers srl -- assiteca spa z73239d7a5 attivazione di n. La storia e attività di Nexive.
#
# ##########################       85
#
# TITOLO: Indici e quotazioni Archivi - FinanzaOnline
# LINK: https://www.finanzaonline.com/notizie/indici-e-quotazioni/
# DESCRIZIONE: ... Asml, Assiteca, Astaldi, Astm, Atlantia, Atlantia, Autogrill Spa, Autogrill Spa ... Banco Popolare, Banco Santander, Banzai, Basf, Basicnet, Bastogi Spa, Bayer ...
#
# ##########################       86
#
# TITOLO: Gazzetta ufficiale della Repubblica italiana. Parte seconda, ...
# LINK: https://books.google.it/books?id=Rw9jKYmyXrQC&pg=RA9-PP1&lpg=RA9-PP1&dq=assiteca+spa&source=bl&ots=UPKY5xfp6i&sig=ACfU3U2439ghhzbJIQsGGEUmQcahhFqYcg&hl=it&sa=X&ved=2ahUKEwi-qMeIx83sAhUQip4KHdoeAs04WhDoATAIegQICBAC
# DESCRIZIONE: 8 7 4 3 9 8 9 ASSITECA · S.p.A. Amministrazione Contratti Assicurativi . . ATTIVITÀ MOBILIARI - S.p.A .. . BALDI GIORGIO - S.p.A. BANCO DI SICILIA Sezione di ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=100&num=10&tbs=
#
# ##########################       87
#
# TITOLO: Trump rilancia: accordo piano fiscale da oltre 1.800 mld ...
# LINK: https://www.finanza.com/Finanza/Notizie_Mondo/Nord_America/notizia/Trump_rilancia_accordo_piano_fiscale_da_oltre_1800_mld_$_p-525233
# DESCRIZIONE: 15 ott 2020 — www.finanza.com è gestito e mantenuto da T-Mediahouse s.r.l, Società sottoposta ad attività di direzione e coordinamento di Triboo S.p.A.
#
# ##########################       88
#
# TITOLO: Vaccino anti-Covid: Moderna punta ad avere approvazione a ...
# LINK: https://www.finanza.com/Finanza/Notizie_Mondo/Nord_America/notizia/Vaccino_antiCovid_Moderna_punta_ad_avere_approvazione_a_di-525320
# DESCRIZIONE: 4 giorni fa — www.finanza.com è gestito e mantenuto da T-Mediahouse s.r.l, Società sottoposta ad attività di direzione e coordinamento di Triboo S.p.A.
#
# ##########################       89
#
# TITOLO: Nobis Compagnia di Assicurazioni S.p.A.
# LINK: https://www.nobis.it/
# DESCRIZIONE: Dalla fusione di Nobis e Filo diretto Assicurazioni nasce la nuova compagnia per darti più innovazione, assistenza, qualità dei servizi.
#
# ##########################       90
#
# TITOLO: 2020–21 Serie B - Wikipedia
# LINK: https://en.wikipedia.org/wiki/2020%E2%80%9321_Serie_B
# DESCRIZIONE: The 2020–21 Serie B (known as the Serie BKT for sponsorship reasons) is the 89th season of ... Marco Mancosu, M908, Banca Popolare Pugliese, Pasta Maffei, Barocco SpA. Monza · Italy ... Mirko Stefani · Joma, Omega Group, Assiteca, Alea.
#
# ##########################       91
#
# TITOLO: Home - quixa
# LINK: https://www.quixa.it/
# DESCRIZIONE: QUIXA Assicurazioni S.p.A.. quixa entra a far parte del Gruppo AXA Italia! Scopri di più. Come ...
#
# ##########################       92
#
# TITOLO: Preventivo assicurazione auto: risparmia sulla RC | Segugio.it
# LINK: https://assicurazioni.segugio.it/assicurazione-auto/preventivo1.html
# DESCRIZIONE: e CercAssicurazioni.it S.r.l. sono interamente controllate da Gruppo MutuiOnline S.p.A., società quotata al Segmento STAR della Borsa Italiana.
#
# ##########################       93
#
# TITOLO: Annunci Offerte di lavoro Verona e provincia - Subito
# LINK: https://www.subito.it/annunci-veneto/vendita/offerte-lavoro/verona/
# DESCRIZIONE: AziendaLenergia S.p.A.. 1. 2 ... 31. Più cercati. Correlati. offerte di lavoro altivole · offerte di lavoro brendola · offerte di lavoro caldogno · offerte di lavoro gaiarine ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=110&num=10&tbs=
#
# ##########################       94
#
# TITOLO: Annunci Offerte di lavoro Verona e provincia - Subito
# LINK: https://www.subito.it/annunci-veneto/vendita/offerte-lavoro/verona/
# DESCRIZIONE: AziendaLenergia S.p.A.. 1. 2 ... 31. Più cercati. Correlati. offerte di lavoro altivole · offerte di lavoro brendola · offerte di lavoro caldogno · offerte di lavoro gaiarine ...
# https://www.google.com/search?nl=en&q=assiteca+spa&start=120&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=130&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=140&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=150&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=160&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=170&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=180&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=190&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=200&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=210&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=220&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=230&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=240&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=250&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=260&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=270&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=280&num=10&tbs=
# https://www.google.com/search?nl=en&q=assiteca+spa&start=290&num=10&tbs=
#
# *******************************
# SONO STATI TROVATI  94  RISULTATI
# *******************************
# []

# %%
from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
import numpy as np
import networkx as nx

# %%
# -*- coding: utf-8 -*- 
from bs4 import BeautifulSoup
url = 'https://www.assiteca.it/'
res = requests.get(url)
htmls = res.content
soup = BeautifulSoup(htmls, 'html.parser')
for po in soup.find_all('p'):
    print po.get_text().encode('utf-8') + "\n\n"
# Out:
#   File "<ipython-input-5-913f165e7460>", line 8
#     print po.get_text().encode('utf-8') + "\n\n"
#           ^
# SyntaxError: invalid syntax
